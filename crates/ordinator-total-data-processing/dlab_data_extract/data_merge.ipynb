# %%
import pandas as pd
import pprint

# %% [markdown]
# # Clustering tool data fetching and processing
#
# Work order **2100058590** / **2100024286** are usable as an example

# %% [markdown]
# ## Useful functions

# %%
def read_csv_file(file_name, columns_dict):
    df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())
    return df.rename(columns=columns_dict)

def write_mid_level_csv_file(df, file_name):
    df.to_csv('./data/mid_' + file_name + '.csv' if '.csv' not in file_name else '')

# %% [markdown]
# ## 1. Work Center tables
#
#
# Tables:
# - CHRD
# - INOB
# - AUSP

# %% [markdown]
# ### Read needed tables

# %% [markdown]
# #### Read CRHD data
#
# Work center header data

# %%
# Needed columns
crhd_columns = {
    'OBJID': 'CRHD_WBS_ID',
    'ARBPL': 'CRHD_WBS_Name',
    'WERKS': 'CRHD_WBS_Plant'
}

# Read CRHD table
crhd_df = read_csv_file("CRHD_V1", crhd_columns)

# Build the WBS name column
crhd_df["CRHD_WBS_Full_Name"] = crhd_df["CRHD_WBS_Plant"] + crhd_df["CRHD_WBS_Name"]

print(crhd_df)
# Out:
#      CRHD_WBS_ID CRHD_WBS_Name CRHD_WBS_Plant CRHD_WBS_Full_Name
# 0       10001014      DRILLING           DK10       DK10DRILLING
# 1       10001016      WELLMAIN           DK10       DK10WELLMAIN
# 2       10001017      WELLSUPV           DK10       DK10WELLSUPV
# 3       10001018      WELLTECH           DK10       DK10WELLTECH
# 4       10001019      MAINONSH           DK10       DK10MAINONSH
# ..           ...           ...            ...                ...
# 405     10001445      MTN-ROPE           DK90       DK90MTN-ROPE
# 406     10001424      VEN-INST           DK90       DK90VEN-INST
# 407     10001431      INP-SITE           DK90       DK90INP-SITE
# 408     10001978      VEN-TURB           DK90       DK90VEN-TURB
# 409     10001974      MTN-PIPF           DK90       DK90MTN-PIPF
#
# [410 rows x 4 columns]

# %% [markdown]
# #### Read INOB data
#
# Work center type

# %%
# Needed columns
inob_columns = {
    'CUOBJ': 'INOB_Object_Number',
    'KLART': 'INOB_Class_Type',
    'OBJEK': 'INOB_Object_Key'
}

# Read INOB table
inob_df = read_csv_file('INOB', inob_columns)

# Filter on KLART == 19
inob_df = inob_df[inob_df['INOB_Class_Type'] == 19]
# Filter on INOB_Object_Key starting with DK
inob_df = inob_df[inob_df['INOB_Object_Key'].str.startswith("DK")]

print(inob_df)
# Out:
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())
#          INOB_Object_Number  INOB_Class_Type INOB_Object_Key
# 1153422             2588124               19    DK90MTN-PIPF
# 1153423             2588126               19    DK30VEN-TURB
# 1154884             2588125               19    DK20VEN-TURB
# 1154885             2588127               19    DK70VEN-TURB
# 1154886             2588128               19    DK90VEN-TURB
# ...                     ...              ...             ...
# 2121029             1663533               19    DK30MTN-TURB
# 2121030             1663751               19    DK80MTN-PAIN
# 2123700             1664209               19     DK70CON-NPT
# 2123701             1664210               19     DK80CON-NPT
# 2123702             1664211               19     DK90CON-NPT
#
# [410 rows x 3 columns]

# %% [markdown]
# #### Read AUSP data
#
# This table contains some objects accessible using a object key, we are here looking for the department order
#
# __
#
# After a deep look, there isn't any work order in denmark getting data from this table

# %%
# Needed columns
ausp_columns = {
    'OBJEK': 'AUSP_Object_Number',
    'KLART': 'AUSP_Class_Type',
    'ATWRT': 'AUSP_Description'
}

# Read AUSP table
ausp_df = read_csv_file('AUSP', ausp_columns)

# Filter on KLART == 19
ausp_df = ausp_df[ausp_df['AUSP_Class_Type'] == 19]

ausp_df["AUSP_Object_Number"] = ausp_df["AUSP_Object_Number"].astype(int)

print(ausp_df)
# Out:
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (2,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())
#          AUSP_Object_Number AUSP_Class_Type AUSP_Description
# 1891801              235125              19             ELEC
# 1891802              235132              19            OTHER
# 1891887              235137              19            OTHER
# 1892013              235156              19             INSP
# 1892014              235182              19            OTHER
# ...                     ...             ...              ...
# 5513578               18305              19             FABM
# 5513579               18306              19            PAINT
# 5513580               18307              19             SCAF
# 5513581               18308              19             TELE
# 5513582               18308              19            OTHER
#
# [1365 rows x 3 columns]

# %%
print(ausp_df["AUSP_Description"].unique())
# Out:
# ['ELEC' 'OTHER' 'INSP' 'MAINT' 'PROD' 'MECH' 'CONS' 'FABM' 'DRILL' 'INST'
#  'TELECOM' 'PERF' 'INTG' 'TELE' 'MNGT' 'PAINT' 'SCAF']

# %% [markdown]
# ### Merge tables

# %% [markdown]
# #### Merge INOB and AUSP

# %%
# Merge INOB and AUSP - nothing to merge atm, so nothing to do to not pollute the model
df_work_center_merged = inob_df.merge(ausp_df, how = 'left', left_on = ['INOB_Object_Number'], right_on = ['AUSP_Object_Number'])

#df_work_center_merged = inob_df.copy()
#df_work_center_merged = df_work_center_merged[df_work_center_merged['INOB_Object_Key'].str.startswith('DK')]
print(df_work_center_merged)

print(df_work_center_merged['AUSP_Object_Number'].unique())
# Out:
#      INOB_Object_Number  INOB_Class_Type INOB_Object_Key  AUSP_Object_Number  \
# 0               2588124               19    DK90MTN-PIPF                 NaN
# 1               2588126               19    DK30VEN-TURB                 NaN
# 2               2588125               19    DK20VEN-TURB                 NaN
# 3               2588127               19    DK70VEN-TURB                 NaN
# 4               2588128               19    DK90VEN-TURB                 NaN
# ..                  ...              ...             ...                 ...
# 405             1663533               19    DK30MTN-TURB                 NaN
# 406             1663751               19    DK80MTN-PAIN                 NaN
# 407             1664209               19     DK70CON-NPT                 NaN
# 408             1664210               19     DK80CON-NPT                 NaN
# 409             1664211               19     DK90CON-NPT                 NaN
#
#     AUSP_Class_Type AUSP_Description
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ..              ...              ...
# 405             NaN              NaN
# 406             NaN              NaN
# 407             NaN              NaN
# 408             NaN              NaN
# 409             NaN              NaN
#
# [410 rows x 6 columns]
# [nan]

# %% [markdown]
# #### Merge CRHD and df_work_center_merged

# %%
# Merge CRHD and df_work_center_merged
df_work_center_merged = df_work_center_merged.merge(crhd_df, how = 'left', left_on = ['INOB_Object_Key'], right_on = ['CRHD_WBS_Full_Name'])

print(df_work_center_merged)
# Out:
#      INOB_Object_Number  INOB_Class_Type INOB_Object_Key  AUSP_Object_Number  \
# 0               2588124               19    DK90MTN-PIPF                 NaN
# 1               2588126               19    DK30VEN-TURB                 NaN
# 2               2588125               19    DK20VEN-TURB                 NaN
# 3               2588127               19    DK70VEN-TURB                 NaN
# 4               2588128               19    DK90VEN-TURB                 NaN
# ..                  ...              ...             ...                 ...
# 405             1663533               19    DK30MTN-TURB                 NaN
# 406             1663751               19    DK80MTN-PAIN                 NaN
# 407             1664209               19     DK70CON-NPT                 NaN
# 408             1664210               19     DK80CON-NPT                 NaN
# 409             1664211               19     DK90CON-NPT                 NaN
#
#     AUSP_Class_Type AUSP_Description  CRHD_WBS_ID CRHD_WBS_Name  \
# 0               NaN              NaN     10001974      MTN-PIPF
# 1               NaN              NaN     10001976      VEN-TURB
# 2               NaN              NaN     10001975      VEN-TURB
# 3               NaN              NaN     10001977      VEN-TURB
# 4               NaN              NaN     10001978      VEN-TURB
# ..              ...              ...          ...           ...
# 405             NaN              NaN     10001085      MTN-TURB
# 406             NaN              NaN     10001303      MTN-PAIN
# 407             NaN              NaN     10001388       CON-NPT
# 408             NaN              NaN     10001389       CON-NPT
# 409             NaN              NaN     10001390       CON-NPT
#
#     CRHD_WBS_Plant CRHD_WBS_Full_Name
# 0             DK90       DK90MTN-PIPF
# 1             DK30       DK30VEN-TURB
# 2             DK20       DK20VEN-TURB
# 3             DK70       DK70VEN-TURB
# 4             DK90       DK90VEN-TURB
# ..             ...                ...
# 405           DK30       DK30MTN-TURB
# 406           DK80       DK80MTN-PAIN
# 407           DK70        DK70CON-NPT
# 408           DK80        DK80CON-NPT
# 409           DK90        DK90CON-NPT
#
# [410 rows x 10 columns]

# %% [markdown]
# ### Filter and rename columns to get the final Work Center merge
#
# Columns kept:
# * CRHD_WBS_ID -> WBS_ID
# * CRHD_WBS_Name -> WBS_Name
# * CRHD_WBS_Plant -> WBS_Plant
# * CRHD_WBS_Full_Name -> WBS_Full_name
# * AUSP_Description -> WBS_Description

# %%
df_work_center_merged = df_work_center_merged[["CRHD_WBS_ID", "CRHD_WBS_Name", "CRHD_WBS_Plant", "CRHD_WBS_Full_Name"]]
df_work_center_merged.rename(inplace = True, columns = {
    "CRHD_WBS_ID": "WBS_ID",
    "CRHD_WBS_Name": "WBS_Name",
    "CRHD_WBS_Plant": "WBS_Plant",
    "CRHD_WBS_Full_Name": "WBS_Full_name",
    "AUSP_Description": "WBS_Description"
})

# %% [markdown]
# ### Save results in csv file

# %%
write_mid_level_csv_file(df_work_center_merged, "work_center")

# %% [markdown]
# ## 2. Work Order and Operations Status tables
#
# Tables:
# - TJ30T
# - JSTO
# - JEST_OR (based on JEST but for Work Orders only)
# - JEST_OV (based on JEST but for Operations only)
# - TJ02T

# %% [markdown]
# ### Read needed tables

# %% [markdown]
# #### Read TJ30T data
#
# This table contains all available status in E - not linked to system
#
# To fetch a code, the code of the status must be used **ESTAT** and the profile of the user i.e. the work order **STSMA**
#
# __
#
# This table contains only status in E, not I, displayed in the "Status with Status Number" and "Status Without Status No." tables.
#
# Data for the status contained in the "Syst. Status" table are stored in E1P_010_TJ02T
#
# __
#
# **SPRAS** column is the laguage used, E for english, D for danish... only keep english

# %%
# Needed columns
tj30t_columns = {
    'ESTAT': 'TJ30T_User_Status_ID', 
    'STSMA': 'TJ30T_User_Status_Profile',
    'SPRAS': 'TJ30T_User_Language',
    'TXT04': 'TJ30T_Textual_Status',
    'TXT30': 'TJ30T_Long_Textual_Status'
}

# Read TJ30T table
tj30t_df = read_csv_file('TJ30T', tj30t_columns)

# Only keep english
tj30t_df = tj30t_df[tj30t_df["TJ30T_User_Language"] == "E"]

print(tj30t_df)

write_mid_level_csv_file(tj30t_df, "tj30t_filtered")
# Out:
#      TJ30T_User_Status_Profile TJ30T_User_Status_ID TJ30T_User_Language  \
# 1                     00000002                E0002                   E
# 8                     00000002                E0003                   E
# 15                    00000003                E0001                   E
# 22                    00000003                E0002                   E
# 29                    00000003                E0003                   E
# ...                        ...                  ...                 ...
# 1972                      TASK                E0002                   E
# 1979                      TASK                E0003                   E
# 1986                      TASK                E0004                   E
# 1993                      TEST                E0001                   E
# 2000                      WARN                E0001                   E
#
#      TJ30T_Textual_Status TJ30T_Long_Textual_Status
# 1                     LKD                    Locked
# 8                    PLIM     Write Plan Line Items
# 15                   0001              Being Tested
# 22                   0002                Productive
# 29                   0003            Being Repaired
# ...                   ...                       ...
# 1972                 GREE             Everything OK
# 1979                  RED    Everything Going Wrong
# 1986                 YELL                  Problems
# 1993                 Test                      Test
# 2000                 WARN           Warning message
#
# [536 rows x 5 columns]

# %% [markdown]
# #### Read TJ02T data
#
# This table contains all status starting by a **I** in the column **ISTAT**.
#
# Keep only english version.

# %%
# Needed columns
tj02t_columns = {
    'ISTAT': 'TJ02T_User_Status_ID',
    'SPRAS': 'TJ02T_User_Language',
    'TXT04': 'TJ02T_Textual_Status',
    'TXT30': 'TJ02T_Long_Textual_Status'
}

# Read the TJ02T file
tj02t_df = read_csv_file("TJ02T", tj02t_columns)

# Only keep th english texts
tj02t_df = tj02t_df[tj02t_df["TJ02T_User_Language"] == "E"]
tj02t_df = tj02t_df.drop(columns = ["TJ02T_User_Language"])

print(tj02t_df)

write_mid_level_csv_file(tj02t_df, "tj02t_filtered")
# Out:
#      TJ02T_User_Status_ID TJ02T_Textual_Status     TJ02T_Long_Textual_Status
# 4                   I0158                 OSTS  Outstanding task(s) exist(s)
# 11                  I0159                 ATCO           All Tasks Completed
# 18                  I0160                 NOTI       Notification (internal)
# 25                  I0161                 NOTE       Notification (external)
# 32                  I0162                 DEFR             Defects Recording
# ...                   ...                  ...                           ...
# 7844                I0038                 CONI      Configuration incomplete
# 7851                I0042                 PREL            Partially released
# 7860                I0043                  LKD                        Locked
# 7868                I0045                 TECO         Technically completed
# 7876                I0046                 CLSD                        Closed
#
# [1112 rows x 3 columns]

# %% [markdown]
# #### Read JSTO data
#
# This table mainly contains the user profile **STSMA** to use for a specific object id i.e. work order defined by **OBJNR**
#
# **OR** for Work orders
#
# **OV** for Operations

# %%
# Needed columns
jsto_columns = {
    'OBJNR': 'JSTO_Object_Number',
    'STSMA': 'JSTO_Status_Profile'
}

# Read TJ30T table
jsto_df = read_csv_file('JSTO', jsto_columns)

# Keep rows about Operations (OV) and Work Orders (OR) only
jsto_df = jsto_df[jsto_df["JSTO_Object_Number"].str.startswith("OV") | jsto_df["JSTO_Object_Number"].str.startswith("OR")]

print(jsto_df)
# Out:
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())
#            JSTO_Object_Number JSTO_Status_Profile
# 0              OR002400035375            PMMTNWOH
# 1        OV100009028900000001            PMMTNWOO
# 2        OV100009028900000002            PMMTNWOO
# 3        OV100009028900000003            PMMTNWOO
# 5              OR002400035376            PMMTNWOH
# ...                       ...                 ...
# 6399937  OV100070992600000002            PMMTNWOO
# 6399938  OV100070992600000003            PMMTNWOO
# 6399939  OV100070992700000001            PMMTNWOO
# 6399940  OV100070992700000002            PMMTNWOO
# 6399941  OV100070992700000003            PMMTNWOO
#
# [2214660 rows x 2 columns]

# %% [markdown]
# #### Read JEST data (E1P_JEST_OR_V1 and E1P_JEST_OV_V1 files)
#
# This table mainly contains all current status **STAT** for a specific object id i.e. work order defined by **OBJNR**
#
# Only status starting with an **E** are kept. **I** status are not processed.

# %%
# Needed columns
jest_columns = {
    'OBJNR': 'JEST_Object_Number',
    'STAT': 'JEST_Object_Status'
}

# Read TJ30T table
jest_or_df = read_csv_file('JEST_OR_V1', jest_columns) # Work order
jest_ov_df = read_csv_file('JEST_OV_V1', jest_columns) # Operations

jest_df = pd.concat([jest_or_df, jest_ov_df])

# Keep only stats starting by E and not I or something else
#jest_df = jest_df[jest_df["JEST_Object_Status"].str.startswith("E")]

print(jest_df)
# Out:
#            JEST_Object_Number JEST_Object_Status
# 0              OR002900001515              E0003
# 1              OR002900001515              E0017
# 2              OR002900001515              I0002
# 3              OR002900001515              I0016
# 4              OR002900001515              I0028
# ...                       ...                ...
# 1539085  OV100051535800000001              E0002
# 1539086  OV100051535800000001              E0004
# 1539087  OV100051535800000001              I0002
# 1539088  OV100051536000000001              E0001
# 1539089  OV100051536000000001              I0045
#
# [2728779 rows x 2 columns]

# %% [markdown]
# ### Merge tables

# %% [markdown]
# #### Merge JEST and JSTO tables

# %%
df_status_merged = jest_df.merge(jsto_df, how = 'left', left_on = ['JEST_Object_Number'], right_on = ['JSTO_Object_Number'])

# %%
df_status_merged = df_status_merged.drop(columns=["JSTO_Object_Number"])

print(df_status_merged)
# Out:
#            JEST_Object_Number JEST_Object_Status JSTO_Status_Profile
# 0              OR002900001515              E0003            PMMTNWOH
# 1              OR002900001515              E0017            PMMTNWOH
# 2              OR002900001515              I0002            PMMTNWOH
# 3              OR002900001515              I0016            PMMTNWOH
# 4              OR002900001515              I0028            PMMTNWOH
# ...                       ...                ...                 ...
# 2728774  OV100051535800000001              E0002            PMMTNWOO
# 2728775  OV100051535800000001              E0004            PMMTNWOO
# 2728776  OV100051535800000001              I0002            PMMTNWOO
# 2728777  OV100051536000000001              E0001            PMMTNWOO
# 2728778  OV100051536000000001              I0045            PMMTNWOO
#
# [2728779 rows x 3 columns]

# %% [markdown]
# #### Merge df_status_merged and TJ30T table
#
# Get **status** corresponding to **status code** and **user profile**.

# %%
df_status_merged = df_status_merged.merge(tj30t_df, how = "left", left_on = ['JSTO_Status_Profile', 'JEST_Object_Status'], right_on = ['TJ30T_User_Status_Profile', 'TJ30T_User_Status_ID'])

# %%
print(df_status_merged[df_status_merged["JEST_Object_Number"] == "OR002100058590"])
# Out:
#        JEST_Object_Number JEST_Object_Status JSTO_Status_Profile  \
# 513697     OR002100058590              E0007            PMMTNWOH
# 513698     OR002100058590              E0030            PMMTNWOH
# 513699     OR002100058590              I0007            PMMTNWOH
# 513700     OR002100058590              I0009            PMMTNWOH
# 513701     OR002100058590              I0016            PMMTNWOH
# 513702     OR002100058590              I0028            PMMTNWOH
# 513703     OR002100058590              I0046            PMMTNWOH
# 513704     OR002100058590              I0215            PMMTNWOH
# 513705     OR002100058590              I0321            PMMTNWOH
# 513706     OR002100058590              I0420            PMMTNWOH
#
#        TJ30T_User_Status_Profile TJ30T_User_Status_ID TJ30T_User_Language  \
# 513697                  PMMTNWOH                E0007                   E
# 513698                  PMMTNWOH                E0030                   E
# 513699                       NaN                  NaN                 NaN
# 513700                       NaN                  NaN                 NaN
# 513701                       NaN                  NaN                 NaN
# 513702                       NaN                  NaN                 NaN
# 513703                       NaN                  NaN                 NaN
# 513704                       NaN                  NaN                 NaN
# 513705                       NaN                  NaN                 NaN
# 513706                       NaN                  NaN                 NaN
#
#        TJ30T_Textual_Status TJ30T_Long_Textual_Status
# 513697                 QCAP  Quality Control Approved
# 513698                 RFRZ              Route Frozen
# 513699                  NaN                       NaN
# 513700                  NaN                       NaN
# 513701                  NaN                       NaN
# 513702                  NaN                       NaN
# 513703                  NaN                       NaN
# 513704                  NaN                       NaN
# 513705                  NaN                       NaN
# 513706                  NaN                       NaN

# %% [markdown]
# #### Merge df_status_merged and TJ02T Table
#
# Get **I Status** corresponding to **I status** code.

# %%
df_status_merged = df_status_merged.merge(tj02t_df, how = "left", left_on = ['JEST_Object_Status'], right_on = ['TJ02T_User_Status_ID'])

# %%
print(df_status_merged[df_status_merged["JEST_Object_Number"] == "OR002100058590"])
# Out:
#        JEST_Object_Number JEST_Object_Status JSTO_Status_Profile  \
# 513697     OR002100058590              E0007            PMMTNWOH
# 513698     OR002100058590              E0030            PMMTNWOH
# 513699     OR002100058590              I0007            PMMTNWOH
# 513700     OR002100058590              I0009            PMMTNWOH
# 513701     OR002100058590              I0016            PMMTNWOH
# 513702     OR002100058590              I0028            PMMTNWOH
# 513703     OR002100058590              I0046            PMMTNWOH
# 513704     OR002100058590              I0215            PMMTNWOH
# 513705     OR002100058590              I0321            PMMTNWOH
# 513706     OR002100058590              I0420            PMMTNWOH
#
#        TJ30T_User_Status_Profile TJ30T_User_Status_ID TJ30T_User_Language  \
# 513697                  PMMTNWOH                E0007                   E
# 513698                  PMMTNWOH                E0030                   E
# 513699                       NaN                  NaN                 NaN
# 513700                       NaN                  NaN                 NaN
# 513701                       NaN                  NaN                 NaN
# 513702                       NaN                  NaN                 NaN
# 513703                       NaN                  NaN                 NaN
# 513704                       NaN                  NaN                 NaN
# 513705                       NaN                  NaN                 NaN
# 513706                       NaN                  NaN                 NaN
#
#        TJ30T_Textual_Status TJ30T_Long_Textual_Status TJ02T_User_Status_ID  \
# 513697                 QCAP  Quality Control Approved                  NaN
# 513698                 RFRZ              Route Frozen                  NaN
# 513699                  NaN                       NaN                I0007
# 513700                  NaN                       NaN                I0009
# 513701                  NaN                       NaN                I0016
# 513702                  NaN                       NaN                I0028
# 513703                  NaN                       NaN                I0046
# 513704                  NaN                       NaN                I0215
# 513705                  NaN                       NaN                I0321
# 513706                  NaN                       NaN                I0420
#
#        TJ02T_Textual_Status     TJ02T_Long_Textual_Status
# 513697                  NaN                           NaN
# 513698                  NaN                           NaN
# 513699                  PRT                       Printed
# 513700                  CNF                     Confirmed
# 513701                  PRC                    Pre-costed
# 513702                 SETC       Settlement rule created
# 513703                 CLSD                        Closed
# 513704                 SSAP                Object created
# 513705                 GMPS         Goods movement posted
# 513706                 MANC  Mat.availability not checked

# %% [markdown]
# ### Filter and Rename columns to get the final Work Order Status and Operation status merges
#
# Columns kept:
# * Work Orders status
#   * JEST_Object_Number -> WO_Object_Number
#   * JEST_Object_Status -> WO_Status_ID
#   * JSTO_Status_Profile -> WO_Status_Profile
#   * TJ30T_Textual_Status -> WO_Status_Code
#   * TJ30T_Long_Textual_Status -> WO_Status_Message
#   * TJ02T_Textual_Status -> WO_I_Status_Code
#   * TJ02T_Long_Textual_Status -> WO_I_Status_Message
#
# * Operations Status
#   * JEST_Object_Number -> OPR_Object_Number
#   * JEST_Object_Status -> OPR_Status_ID
#   * JSTO_Status_Profile -> OPR_Status_Profile
#   * TJ30T_Textual_Status -> OPR_Status_Code
#   * TJ30T_Long_Textual_Status -> OPR_Status_Message
#   * TJ02T_Textual_Status -> OPR_I_Status_Code
#   * TJ02T_Long_Textual_Status -> OPR_I_Status_Message

# %%
df_status_merged = df_status_merged[["JEST_Object_Number", "JEST_Object_Status", "JSTO_Status_Profile", "TJ30T_Textual_Status", "TJ30T_Long_Textual_Status", "TJ02T_Textual_Status", "TJ02T_Long_Textual_Status"]]

def get_df(column_names_prefix_value, filter_prefix_value):
    df_local = df_status_merged[df_status_merged["JEST_Object_Number"].str.startswith(filter_prefix_value)]

    df_local.rename(inplace = True, columns = {
        "JEST_Object_Number": column_names_prefix_value + "_Object_Number", 
        "JEST_Object_Status": column_names_prefix_value + "_Status_ID", 
        "JSTO_Status_Profile": column_names_prefix_value + "_Status_Profile", 
        "TJ30T_Textual_Status": column_names_prefix_value + "_E_Status_Code", 
        "TJ30T_Long_Textual_Status": column_names_prefix_value + "_E_Status_Message",
        "TJ02T_Textual_Status": column_names_prefix_value + "_I_Status_Code", 
        "TJ02T_Long_Textual_Status": column_names_prefix_value + "_I_Status_Message"
        }
    )
    df_local.replace(pd.NA, "", inplace = True)

    return df_local

df_wo_status_merged = get_df("WO", "OR")
df_opr_status_merged = get_df("OPR", "OV")
# Out:
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\2758546654.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_local.rename(inplace = True, columns = {
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\2758546654.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_local.replace(pd.NA, "", inplace = True)
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\2758546654.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_local.rename(inplace = True, columns = {
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\2758546654.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_local.replace(pd.NA, "", inplace = True)

# %% [markdown]
# ### Save the file

# %%
write_mid_level_csv_file(df_wo_status_merged, "work_orders_status")
write_mid_level_csv_file(df_opr_status_merged, "operations_status")

# %% [markdown]
# ## 3. Functional location
#
# Tables:
# - ILOA_V1
# - IFLOS

# %% [markdown]
# ### Read and format data

# %% [markdown]
# #### Read ILOA data

# %%
# Needed columns
iloa_columns = {
    'ILOAN': 'ILOAN_Technical_Location_ID',
    'TPLNR': 'ILOAN_Functional_Location_ID',
    'SWERK': 'ILOAN_Location_Plant_Code',
    'MSGRP': 'ILOAN_Location_Room'
}

# Read ILOA table
iloa_df = read_csv_file("ILOA_V1", iloa_columns)

print(iloa_df)
# Out:
#         ILOAN_Technical_Location_ID ILOAN_Functional_Location_ID  \
# 0                           2512161         ?0100000000000632852
# 1                           2512180         ?0100000000000634098
# 2                           1180579         ?0100000000000580069
# 3                           1180580         ?0100000000000580070
# 4                           1180581         ?0100000000000580071
# ...                             ...                          ...
# 489421                      2668856         ?0100000000000646315
# 489422                      2668874         ?0100000000000649833
# 489423                      2668873         ?0100000000000649833
# 489424                      2668907         ?0100000000000649698
# 489425                      2668911         ?0100000000000733468
#
#        ILOAN_Location_Plant_Code ILOAN_Location_Room
# 0                           DK30                 NaN
# 1                           DK30                 NaN
# 2                           DK60                 NaN
# 3                           DK60                 NaN
# 4                           DK60                 NaN
# ...                          ...                 ...
# 489421                      DK80                 NaN
# 489422                      DK80                 NaN
# 489423                      DK80                 NaN
# 489424                      DK40                 NaN
# 489425                      DK20                 NaN
#
# [489426 rows x 4 columns]
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())

# %% [markdown]
# #### Read IFLOS data

# %%
# Needed columns
iflos_columns = {
    'TPLNR': 'IFLOS_Functional_Location_ID',
    'STRNO': 'IFLOS_Functional_Location_Name',
}

# Read IFLOS table
iflos_df = read_csv_file("IFLOS", iflos_columns)

print(iflos_df)
# Out:
#        IFLOS_Functional_Location_ID     IFLOS_Functional_Location_Name
# 0              ?0100000000000594008  HB /A /10/HBA-6-PTS-030-4103-FE-U
# 1              ?0100000000000594009  HB /A /10/HBA-6-PTS-030-4293-FC-T
# 2              ?0100000000000594011           HB /A /10/HBAA-XCV-30109
# 3              ?0100000000000594014           HB /A /10/HBAA-XCV-30158
# 4              ?0100000000000594016  HB /A /10/HBA-6-PTS-033-4007-FC-U
# ...                             ...                                ...
# 241366         ?0100000000000974789       SV /A /86/INSP-OOS-EQUIPMENT
# 241367         ?0100000000000977560           TW /C /78/TWCD-ZSC-61630
# 241368         ?0100000000000977561           TW /B /78/TWBD-ZSC-61630
# 241369         ?0100000000000977562           TE /E /78/TEEE-ZSC-61630
# 241370         ?0100000000000977563           TE /B /78/TEBD-ZSC-61630
#
# [241371 rows x 2 columns]

# %% [markdown]
# ### Merge the data - ILOA and IFLOS

# %%
df_functional_location_merged = iloa_df.merge(iflos_df, how = "left", left_on = ["ILOAN_Functional_Location_ID"], right_on = ["IFLOS_Functional_Location_ID"])

print(df_functional_location_merged)
# Out:
#         ILOAN_Technical_Location_ID ILOAN_Functional_Location_ID  \
# 0                           2512161         ?0100000000000632852
# 1                           2512180         ?0100000000000634098
# 2                           1180579         ?0100000000000580069
# 3                           1180580         ?0100000000000580070
# 4                           1180581         ?0100000000000580071
# ...                             ...                          ...
# 504639                      2668856         ?0100000000000646315
# 504640                      2668874         ?0100000000000649833
# 504641                      2668873         ?0100000000000649833
# 504642                      2668907         ?0100000000000649698
# 504643                      2668911         ?0100000000000733468
#
#        ILOAN_Location_Plant_Code ILOAN_Location_Room  \
# 0                           DK30                 NaN
# 1                           DK30                 NaN
# 2                           DK60                 NaN
# 3                           DK60                 NaN
# 4                           DK60                 NaN
# ...                          ...                 ...
# 504639                      DK80                 NaN
# 504640                      DK80                 NaN
# 504641                      DK80                 NaN
# 504642                      DK40                 NaN
# 504643                      DK20                 NaN
#
#        IFLOS_Functional_Location_ID      IFLOS_Functional_Location_Name
# 0              ?0100000000000632852               HW /A /07/HWAA-P-5902
# 1              ?0100000000000634098       HW /A /10/HEA06-MANUAL-VALVES
# 2              ?0100000000000580069            HD /A /23/HDAD-BDV-33035
# 3              ?0100000000000580070           HD /A /23/HDAD-ESDV-33032
# 4              ?0100000000000580071  HD /A /28/HDA-0.5-DP-041-0002-AS-U
# ...                             ...                                 ...
# 504639         ?0100000000000646315                  GO /B /78/GB-M-712
# 504640         ?0100000000000649833                 GO /E /78/GEA-M-716
# 504641         ?0100000000000649833                 GO /E /78/GEA-M-716
# 504642         ?0100000000000649698               DF /G /54/DFGA-A-3590
# 504643         ?0100000000000733468                               TE /H
#
# [504644 rows x 6 columns]

# %% [markdown]
# ### Filter and Rename columns to get the final Work Order Status merge
#
# Columns kept:
# * ILOAN_Technical_Location_ID -> FLOC_Technical_ID
# * ILOAN_Functional_Location_ID -> FLOC_Functional_ID
# * IFLOS_Functional_Location_Name -> FLOC_Name

# %%
# drop useless columns
df_functional_location_merged = df_functional_location_merged[["ILOAN_Technical_Location_ID", "ILOAN_Functional_Location_ID", "IFLOS_Functional_Location_Name", "ILOAN_Location_Room", "ILOAN_Location_Plant_Code"]]

# rename columns
df_functional_location_merged.rename(inplace = True, columns = {
    "ILOAN_Technical_Location_ID": "FLOC_Technical_ID", 
    "ILOAN_Functional_Location_ID": "FLOC_Functional_ID", 
    "IFLOS_Functional_Location_Name": "FLOC_Name",
    "ILOAN_Location_Plant_Code": "FLOC_Plant_Code"
})


# drop duplicates (keep last registered entry for FLOC_Functional_ID)
df_functional_location_merged.drop_duplicates(subset = ['FLOC_Technical_ID', 'FLOC_Functional_ID'], keep = 'last', inplace = True)

# reset index
df_functional_location_merged.reset_index(inplace = True, drop = True)

# drop created index column

print(df_functional_location_merged)
# Out:
#         FLOC_Technical_ID    FLOC_Functional_ID  \
# 0                 2512161  ?0100000000000632852
# 1                 2512180  ?0100000000000634098
# 2                 1180579  ?0100000000000580069
# 3                 1180580  ?0100000000000580070
# 4                 1180581  ?0100000000000580071
# ...                   ...                   ...
# 489421            2668856  ?0100000000000646315
# 489422            2668874  ?0100000000000649833
# 489423            2668873  ?0100000000000649833
# 489424            2668907  ?0100000000000649698
# 489425            2668911  ?0100000000000733468
#
#                                  FLOC_Name ILOAN_Location_Room FLOC_Plant_Code
# 0                    HW /A /07/HWAA-P-5902                 NaN            DK30
# 1            HW /A /10/HEA06-MANUAL-VALVES                 NaN            DK30
# 2                 HD /A /23/HDAD-BDV-33035                 NaN            DK60
# 3                HD /A /23/HDAD-ESDV-33032                 NaN            DK60
# 4       HD /A /28/HDA-0.5-DP-041-0002-AS-U                 NaN            DK60
# ...                                    ...                 ...             ...
# 489421                  GO /B /78/GB-M-712                 NaN            DK80
# 489422                 GO /E /78/GEA-M-716                 NaN            DK80
# 489423                 GO /E /78/GEA-M-716                 NaN            DK80
# 489424               DF /G /54/DFGA-A-3590                 NaN            DK40
# 489425                               TE /H                 NaN            DK20
#
# [489426 rows x 5 columns]

# %% [markdown]
# ### Save the data

# %%
write_mid_level_csv_file(df_functional_location_merged, "functional_locations")

# %% [markdown]
# ## 4. Work Order tables
#
# Tables:
# * AFKO
# * AUFK
# * AFIH
# * YTLXXPM_BICNOLTX_V1 (notifications)
# * QMEL (notifications)

# %% [markdown]
# ### Read and format data

# %% [markdown]
# #### Read AFIH data

# %%
# Needed columns
afih_columns = {
    'AUFNR': 'AFIH_WO_Number', 
    'GEWRK': 'AFIH_WO_WBS_ID', 
    'PRIOK': 'AFIH_WO_Priority', 
    'REVNR': 'AFIH_WO_Revision', 
    'INGPR': 'AFIH_WO_Planner_Group', 
    'ILART': 'AFIH_WO_Activity_Type', 
    'QMNUM': 'AFIH_WO_Notification_Number',
    'ILOAN': 'AFIH_WO_Functional_Location_Number', # Main functional location
    'OBKNR': 'AFIH_WO_Plan_Maintenance_Number', # Secondary functional location
    'WARPL': 'AFIH_WO_Maintenance_Plan_Name',
    'ANLZU': 'AFIH_WO_System_Condition'
}

# Read AFIH table
afih_df = read_csv_file("AFIH_V1", afih_columns)
#print(afih_df)

# Filter on nan worker order id - I don't know if we keep orders without any WBS, the next line does it if needed
#afih_df = afih_df[afih_df['AFIH_WO_WBS_ID'].notna()]
#afih_df = afih_df[afih_df['AFIH_WO_Number'].notna()]

print(afih_df)
# Out:
#         AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 0           2300009145                3                             2558055
# 1           2400352096                A                             2610303
# 2           2100114335                3                             2571638
# 3           2100114433                3                             2604131
# 4           2800031347                2                             2529524
# ...                ...              ...                                 ...
# 121025      2100087418                4                             2273323
# 121026      2100086200                2                             2260911
# 121027      2100086201                2                             2260913
# 121028      2800024552                3                             2260977
# 121029      2900000760                3                             2261013
#
#        AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 0                             A                   MIN        10001172
# 1                             A                   INP        10001416
# 2                             A                   MMS        10001033
# 3                             A                   MFM        10001039
# 4                             A                   MFM        10001265
# ...                         ...                   ...             ...
# 121025                        A                   MFM        10001127
# 121026                        A                   MEL        10001122
# 121027                        A                   MEL        10001122
# 121028                        A                   CON        10001026
# 121029                        A                   WLD        10001372
#
#        AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 0                                NaN                           572308
# 1                        DKGO-PVI128                           580945
# 2                                NaN                           578916
# 3                                NaN                           579923
# 4                                NaN                                0
# ...                              ...                              ...
# 121025                           NaN                           448492
# 121026                           NaN                           442857
# 121027                           NaN                           442858
# 121028                           NaN                                0
# 121029                           NaN                           442897
#
#        AFIH_WO_Revision AFIH_WO_Activity_Type  AFIH_WO_Notification_Number
# 0                   NaN                    SO                 1.300012e+09
# 1                  NOSD                    RO                 1.400367e+09
# 2                   NaN                    BK                 1.100152e+09
# 3                   NaN                    BK                 1.100152e+09
# 4                   NaN                    MD                          NaN
# ...                 ...                   ...                          ...
# 121025             NOSD                    PC                 1.500006e+09
# 121026             NOSD                    BK                 1.100113e+09
# 121027             NOSD                    BK                 1.100113e+09
# 121028              NaN                    MD                          NaN
# 121029              NaN                    SP                 1.200021e+09
#
# [121030 rows x 11 columns]

# %%
print(afih_df[afih_df["AFIH_WO_Notification_Number"] == 1100025915])
# Out:
#        AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 78306      2100027283                4                             1374014
#
#       AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 78306                        C                   MFM        10001300
#
#       AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 78306                           NaN                           143847
#
#       AFIH_WO_Revision AFIH_WO_Activity_Type  AFIH_WO_Notification_Number
# 78306           GOFRYS                    DE                 1.100026e+09

# %% [markdown]
# #### Read AFKO data

# %%
# Needed columns
afko_columns = {
    'AUFNR': 'AFKO_WO_Number',
    'AUFPL': 'AFKO_WO_Operation_ID',
    'GSTRS': 'AFKO_WO_Scheduled_Start_Date',
    'GSTRP': "AFKO_WO_Basic_Start_Date",
    'GLTRP': "AFKO_WO_Basic_End_Date",
    'AUFNT': "AFKO_WO_SubNetwork_ID"
}

# Read AFKO table
afko_df = read_csv_file("AFKO_V1", afko_columns)
print(afko_df)
# Out:
#        AFKO_WO_Number  AFKO_WO_Basic_End_Date  AFKO_WO_Basic_Start_Date  \
# 0          2300008768                20270418                  20240501
# 1          2300008769                20270418                  20240501
# 2          2300008770                20270418                  20240501
# 3          2300008771                20270418                  20240501
# 4          2300008772                20270418                  20240501
# ...               ...                     ...                       ...
# 591456     2400266965                20230727                  20230727
# 591457     2400266966                20240110                  20230807
# 591458     2400266967                20230630                  20230630
# 591459     2400266971                20230816                  20230816
# 591460     2400266972                20230822                  20230822
#
#         AFKO_WO_Scheduled_Start_Date  AFKO_WO_Operation_ID  \
# 0                           20240501            1000658262
# 1                           20240501            1000658263
# 2                           20240501            1000658264
# 3                           20240501            1000658265
# 4                           20240501            1000658266
# ...                              ...                   ...
# 591456                      20230727            1000519724
# 591457                      20230807            1000519725
# 591458                      20230630            1000519726
# 591459                      20230816            1000519730
# 591460                      20230822            1000519731
#
#        AFKO_WO_SubNetwork_ID
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 591456                   NaN
# 591457                   NaN
# 591458                   NaN
# 591459                   NaN
# 591460                   NaN
#
# [591461 rows x 6 columns]
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (2,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())

# %% [markdown]
# #### Read AUFK data

# %%
# Needed columns
aufk_columns = {
    'AUFNR': 'AUFK_WO_Number', 
    'KTEXT': 'AUFK_WO_Header_Description', 
    'AUART': 'AUFK_WO_Order_Type', 
    'PHAS0': 'AUFK_WO_Phase_Order_Created', 
    'PHAS1': 'AUFK_WO_Phase_Order_Released', 
    'ZZ_OLAFD': 'AUFK_WO_Original_Deadline', 
    'ZZ_EASD': 'AUFK_WO_Earliest_Allowed_Start_Date', 
    'ZZ_LAFD': 'AUFK_WO_Latest_Allowed_Finish_Date', 
    'OBJNR': 'AUFK_WO_Object_Number'
}

# Read AUFK table
aufk_df = read_csv_file("AUFK_V1", aufk_columns)
print(aufk_df)
# Out:
#        AUFK_WO_Number AUFK_WO_Order_Type  \
# 0        002900001591                WSO
# 1        002900001587                WSO
# 2        002900001515                WSO
# 3        002900001542                WSO
# 4        002900001585                WSO
# ...               ...                ...
# 121590     2300005429                WRO
# 121591     2300005420                WRO
# 121592     2300005425                WRO
# 121593     2300005428                WRO
# 121594     2900000516                WSO
#
#                      AUFK_WO_Header_Description AUFK_WO_Phase_Order_Created  \
# 0                       Rolf Scheduled WHM 2024                         NaN
# 1                 DFB01,Plug retrieval,WL,19862                         NaN
# 2                        Scheduled WHM SAN 2024                         NaN
# 3                         Scheduled WHM 2024 DD                           X
# 4                        Scheduled WHM KRA 2024                         NaN
# ...                                         ...                         ...
# 121590                   Replaced by 2300006187                         NaN
# 121591  HDAORR2 Demol of switch ABB Step B plus                         NaN
# 121592            DK70 - REPLACED BY 2300009184                         NaN
# 121593            DK40 - REPLACED BY 2300008269                         NaN
# 121594          Gorm Annuli Pressure Monitoring                         NaN
#
#        AUFK_WO_Phase_Order_Released AUFK_WO_Object_Number  \
# 0                                 X        OR002900001591
# 1                               NaN        OR002900001587
# 2                                 X        OR002900001515
# 3                               NaN        OR002900001542
# 4                                 X        OR002900001585
# ...                             ...                   ...
# 121590                            X        OR002300005429
# 121591                          NaN        OR002300005420
# 121592                            X        OR002300005425
# 121593                            X        OR002300005428
# 121594                          NaN        OR002900000516
#
#         AUFK_WO_Original_Deadline  AUFK_WO_Latest_Allowed_Finish_Date  \
# 0                        20241127                            20241127
# 1                        20240713                            20240713
# 2                        20241027                            20241027
# 3                        20241110                            20241110
# 4                        20241125                            20241125
# ...                           ...                                 ...
# 121590                   20260403                            20260403
# 121591                   20230601                            20230601
# 121592                   20260403                            20260403
# 121593                   20260403                            20260403
# 121594                   20220409                            20220409
#
#         AUFK_WO_Earliest_Allowed_Start_Date
# 0                                  20240715
# 1                                  20240529
# 2                                  20240614
# 3                                  20240628
# 4                                  20240713
# ...                                     ...
# 121590                             20231016
# 121591                             20230417
# 121592                             20231016
# 121593                             20231016
# 121594                             20220228
#
# [121595 rows x 9 columns]
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())

# %% [markdown]
# #### Read YTLXXPM_BICNOLTX_V1 table
#
# Keep only notifications related to a maintenance work order

# %%
# Needed columns
notif_columns = {
    'QMNUM': 'NOTIF_Number',
    'YROWNUM': 'NOTIF_Row_Number',
    'LONGTEXT': 'NOTIF_Row_Text'
}

# Read notifications table
notif_df = read_csv_file("YTLXXPM_BICNOLTX_V1", notif_columns)


# Keep only notifications linked to a work order in AFIH
notif_df = notif_df[notif_df["NOTIF_Number"].isin(afih_df["AFIH_WO_Notification_Number"].unique())]

# Drop duplicated rows
notif_df.drop_duplicates(subset = ["NOTIF_Number", "NOTIF_Row_Number"], inplace = True)

# Sort the df by notif number and row number
notif_df = notif_df.sort_values(["NOTIF_Number", "NOTIF_Row_Number"])

print(notif_df)
# Out:
#           NOTIF_Number  NOTIF_Row_Number  \
# 1123541     1100025915                 1
# 1123542     1100025915                 2
# 1123543     1100025915                 3
# 1123544     1100025915                 4
# 1123545     1100025915                 5
# ...                ...               ...
# 14757874    1700005935                 1
# 14757875    1700005935                 2
# 14757876    1700005939                 1
# 14757877    1700005939                 2
# 14757878    1700005939                 3
#
#                                              NOTIF_Row_Text
# 1123541     .05.2013 05:55:41 Mikael Borre Thomsen (MBT009)
# 1123542   oolstykke samt checkventil nedstrøms GC-HCV-09...
# 1123543   O ifbm kommende frysejob. Spoolstykke (mat: 20...
# 1123544   bpakkelager og ny checkventil bestilles på den...
# 1123545                                             bpakke.
# ...                                                     ...
# 14757874    08.10.2024 15:11:57 CET Lars NIELSEN (J0516237)
# 14757875                                     Procurment WCC
# 14757876  09.10.2024 13:14:04 CET Nis Hogh LARSEN (L0516...
# 14757877  Network Segregation implementation according p...
# 14757878                                support by telecom.
#
# [514000 rows x 3 columns]

# %%
# Group by with string concatenation - each row of the notification text is contained in a row of the file, all linked by the notification number and the row number
notif_df["NOTIF_Row_Text"] = notif_df["NOTIF_Row_Text"].astype(str)
notif_processed_df = notif_df[["NOTIF_Number", "NOTIF_Row_Text"]].groupby(["NOTIF_Number"])["NOTIF_Row_Text"].agg('\n'.join)

print(notif_processed_df)
# Out:
# NOTIF_Number
# 1100025915    .05.2013 05:55:41 Mikael Borre Thomsen (MBT009...
# 1100025916    Work to be done\n-06-2009 hras\nr kom pludseli...
# 1100025917    .02.2018 07:43:39 UTC Morten Jensen (MJE099) P...
# 1100025918    .12.2011 18:41:26 Hans-Jørgen Andreasen (HJA03...
# 1100025919    .03.2012 10:35:35 Frank Lemmiche (FLE008)\n co...
#                                     ...
# 1700005928    04.10.2024 10:25:01 CET Jens Christian SIMONSE...
# 1700005929    04.10.2024 10:26:14 CET Jens Christian SIMONSE...
# 1700005933    08.10.2024 12:21:44 CET Rene GRINDERSLEV (L051...
# 1700005935    08.10.2024 15:11:57 CET Lars NIELSEN (J0516237...
# 1700005939    09.10.2024 13:14:04 CET Nis Hogh LARSEN (L0516...
# Name: NOTIF_Row_Text, Length: 53063, dtype: object

# %%
print(notif_processed_df[1100025915])
# Out:
# .05.2013 05:55:41 Mikael Borre Thomsen (MBT009)
# oolstykke samt checkventil nedstrøms GC-HCV-090006 skal udskiftes til
# O ifbm kommende frysejob. Spoolstykke (mat: 200227751) sendt på
# bpakkelager og ny checkventil bestilles på denne WO ligeledes til
# bpakke.
# rk order closed as part of Backlog rationalization
# oject - Ref. NM1800007341

# %%
# save mid file
write_mid_level_csv_file(notif_processed_df, "notif_processed")

# %% [markdown]
# #### Read QMEL data
#
# Keep only notifications related to a maintenance work order

# %%
# Needed columns
qmel_columns = {
    'QMNUM': 'QMEL_Notification_Number',
    'QMDAT': 'QMEL_Malfunction_Started',
    'ERDAT': 'QMEL_Notification_Created'
}

# Read notifications table
qmel_df = read_csv_file("QMEL_V1", qmel_columns)


# Keep only notifications linked to a work order in AFIH
qmel_df = qmel_df[qmel_df["QMEL_Notification_Number"].isin(afih_df["AFIH_WO_Notification_Number"].unique())]

print(qmel_df)
# Out:
#         QMEL_Notification_Number  QMEL_Notification_Created  \
# 0                     1400352484                   20240426
# 1                     1100147446                   20240426
# 2                     1100147453                   20240426
# 3                     1100147461                   20240426
# 4                     1100147462                   20240426
# ...                          ...                        ...
# 107039                1400284084                   20230501
# 107040                1400284090                   20230501
# 107041                1100118367                   20230501
# 107042                1100117478                   20230419
# 107044                1100117500                   20230420
#
#         QMEL_Malfunction_Started
# 0                       20240426
# 1                       20240426
# 2                       20240426
# 3                       20240426
# 4                       20240426
# ...                          ...
# 107039                  20230501
# 107040                  20230501
# 107041                  20230501
# 107042                  20230419
# 107044                  20230420
#
# [89908 rows x 3 columns]

# %% [markdown]
# ### Merge the data

# %% [markdown]
# #### Merge AFIH and AFKO

# %%
# Merge AFKO and AUFK
df_work_order_merged = afih_df.merge(afko_df, how = 'left', left_on = ['AFIH_WO_Number'], right_on = ['AFKO_WO_Number'])

print(df_work_order_merged)
# Out:
#        AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 0          2300009145                3                             2558055
# 1          2400352096                A                             2610303
# 2          2100114335                3                             2571638
# 3          2100114433                3                             2604131
# 4          2800031347                2                             2529524
# ...               ...              ...                                 ...
# 121025     2100087418                4                             2273323
# 121026     2100086200                2                             2260911
# 121027     2100086201                2                             2260913
# 121028     2800024552                3                             2260977
# 121029     2900000760                3                             2261013
#
#        AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 0                             A                   MIN        10001172
# 1                             A                   INP        10001416
# 2                             A                   MMS        10001033
# 3                             A                   MFM        10001039
# 4                             A                   MFM        10001265
# ...                         ...                   ...             ...
# 121025                        A                   MFM        10001127
# 121026                        A                   MEL        10001122
# 121027                        A                   MEL        10001122
# 121028                        A                   CON        10001026
# 121029                        A                   WLD        10001372
#
#        AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 0                                NaN                           572308
# 1                        DKGO-PVI128                           580945
# 2                                NaN                           578916
# 3                                NaN                           579923
# 4                                NaN                                0
# ...                              ...                              ...
# 121025                           NaN                           448492
# 121026                           NaN                           442857
# 121027                           NaN                           442858
# 121028                           NaN                                0
# 121029                           NaN                           442897
#
#        AFIH_WO_Revision AFIH_WO_Activity_Type  AFIH_WO_Notification_Number  \
# 0                   NaN                    SO                 1.300012e+09
# 1                  NOSD                    RO                 1.400367e+09
# 2                   NaN                    BK                 1.100152e+09
# 3                   NaN                    BK                 1.100152e+09
# 4                   NaN                    MD                          NaN
# ...                 ...                   ...                          ...
# 121025             NOSD                    PC                 1.500006e+09
# 121026             NOSD                    BK                 1.100113e+09
# 121027             NOSD                    BK                 1.100113e+09
# 121028              NaN                    MD                          NaN
# 121029              NaN                    SP                 1.200021e+09
#
#        AFKO_WO_Number  AFKO_WO_Basic_End_Date  AFKO_WO_Basic_Start_Date  \
# 0          2300009145              20251020.0                20251019.0
# 1          2400352096              20251028.0                20251019.0
# 2          2100114335              20240727.0                20240727.0
# 3          2100114433              20240728.0                20240728.0
# 4          2800031347              20221001.0                20221001.0
# ...               ...                     ...                       ...
# 121025     2100087418              20230918.0                20230911.0
# 121026     2100086200              20231125.0                20231120.0
# 121027     2100086201              20231219.0                20231218.0
# 121028     2800024552              20230504.0                20230501.0
# 121029     2900000760              20230413.0                20230413.0
#
#         AFKO_WO_Scheduled_Start_Date  AFKO_WO_Operation_ID  \
# 0                         20251019.0          1.000668e+09
# 1                         20251019.0          1.000678e+09
# 2                         20240727.0          1.000675e+09
# 3                         20240728.0          1.000677e+09
# 4                         20221001.0          1.000653e+09
# ...                              ...                   ...
# 121025                    20230911.0          1.000512e+09
# 121026                    20231120.0          1.000504e+09
# 121027                    20231218.0          1.000504e+09
# 121028                    20230501.0          1.000505e+09
# 121029                    20230413.0          1.000505e+09
#
#        AFKO_WO_SubNetwork_ID
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 121025                   NaN
# 121026                   NaN
# 121027                   NaN
# 121028            99000027.0
# 121029                   NaN
#
# [121030 rows x 17 columns]

# %% [markdown]
# #### Merge AUFK and df_work_order_merged

# %%
# Merge AFKO and AUFK
df_work_order_merged = df_work_order_merged.merge(aufk_df, how = 'left', left_on = ['AFIH_WO_Number'], right_on = ['AUFK_WO_Number'])

print(df_work_order_merged)
# Out:
#        AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 0          2300009145                3                             2558055
# 1          2400352096                A                             2610303
# 2          2100114335                3                             2571638
# 3          2100114433                3                             2604131
# 4          2800031347                2                             2529524
# ...               ...              ...                                 ...
# 121025     2100087418                4                             2273323
# 121026     2100086200                2                             2260911
# 121027     2100086201                2                             2260913
# 121028     2800024552                3                             2260977
# 121029     2900000760                3                             2261013
#
#        AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 0                             A                   MIN        10001172
# 1                             A                   INP        10001416
# 2                             A                   MMS        10001033
# 3                             A                   MFM        10001039
# 4                             A                   MFM        10001265
# ...                         ...                   ...             ...
# 121025                        A                   MFM        10001127
# 121026                        A                   MEL        10001122
# 121027                        A                   MEL        10001122
# 121028                        A                   CON        10001026
# 121029                        A                   WLD        10001372
#
#        AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 0                                NaN                           572308
# 1                        DKGO-PVI128                           580945
# 2                                NaN                           578916
# 3                                NaN                           579923
# 4                                NaN                                0
# ...                              ...                              ...
# 121025                           NaN                           448492
# 121026                           NaN                           442857
# 121027                           NaN                           442858
# 121028                           NaN                                0
# 121029                           NaN                           442897
#
#        AFIH_WO_Revision AFIH_WO_Activity_Type  ...  AFKO_WO_SubNetwork_ID  \
# 0                   NaN                    SO  ...                    NaN
# 1                  NOSD                    RO  ...                    NaN
# 2                   NaN                    BK  ...                    NaN
# 3                   NaN                    BK  ...                    NaN
# 4                   NaN                    MD  ...                    NaN
# ...                 ...                   ...  ...                    ...
# 121025             NOSD                    PC  ...                    NaN
# 121026             NOSD                    BK  ...                    NaN
# 121027             NOSD                    BK  ...                    NaN
# 121028              NaN                    MD  ...             99000027.0
# 121029              NaN                    SP  ...                    NaN
#
#        AUFK_WO_Number  AUFK_WO_Order_Type  \
# 0          2300009145                 WRO
# 1          2400352096                 WPM
# 2          2100114335                 WDF
# 3          2100114433                 WDF
# 4                 NaN                 NaN
# ...               ...                 ...
# 121025     2100087418                 WDF
# 121026     2100086200                 WDF
# 121027     2100086201                 WDF
# 121028     2800024552                 WCC
# 121029            NaN                 NaN
#
#                       AUFK_WO_Header_Description  AUFK_WO_Phase_Order_Created  \
# 0              F83 Enable comm to new HMI serves                            X
# 1                 PVI Intermediate - GOFD-E-4202                            X
# 2                TEC Crane - Key cylinder defect                            X
# 3       TEE-2-FLS-040-8652-AD-U - Weld Corrosion                            X
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 121025  ANOCR DFB - Repair and Paint Diagonal Br                          NaN
# 121026    Troubleshoot Firedamper DFGA-FD-123031                          NaN
# 121027    Troubleshoot Firedamper DFGA-FD-130231                          NaN
# 121028  TE-N1-5.3.12A install 12" J-Tube support                          NaN
# 121029                                       NaN                          NaN
#
#         AUFK_WO_Phase_Order_Released AUFK_WO_Object_Number  \
# 0                                NaN        OR002300009145
# 1                                NaN        OR002400352096
# 2                                NaN        OR002100114335
# 3                                NaN        OR002100114433
# 4                                NaN                   NaN
# ...                              ...                   ...
# 121025                           NaN        OR002100087418
# 121026                           NaN        OR002100086200
# 121027                           NaN        OR002100086201
# 121028                           NaN        OR002800024552
# 121029                           NaN                   NaN
#
#        AUFK_WO_Original_Deadline AUFK_WO_Latest_Allowed_Finish_Date  \
# 0                     20241201.0                         20241201.0
# 1                     20251231.0                         20251231.0
# 2                     20241209.0                         20241209.0
# 3                     20241210.0                         20241210.0
# 4                            NaN                                NaN
# ...                          ...                                ...
# 121025                20251231.0                         20251231.0
# 121026                20230617.0                         20230617.0
# 121027                20230617.0                         20230617.0
# 121028                       0.0                                0.0
# 121029                       NaN                                NaN
#
#        AUFK_WO_Earliest_Allowed_Start_Date
# 0                               20240719.0
# 1                               20251019.0
# 2                               20240727.0
# 3                               20240728.0
# 4                                      NaN
# ...                                    ...
# 121025                          20230911.0
# 121026                          20230503.0
# 121027                          20230503.0
# 121028                                 0.0
# 121029                                 NaN
#
# [121030 rows x 26 columns]

# %%
print(df_work_order_merged.columns)
# Out:
# Index(['AFIH_WO_Number', 'AFIH_WO_Priority',
#        'AFIH_WO_Functional_Location_Number', 'AFIH_WO_System_Condition',
#        'AFIH_WO_Planner_Group', 'AFIH_WO_WBS_ID',
#        'AFIH_WO_Maintenance_Plan_Name', 'AFIH_WO_Plan_Maintenance_Number',
#        'AFIH_WO_Revision', 'AFIH_WO_Activity_Type',
#        'AFIH_WO_Notification_Number', 'AFKO_WO_Number',
#        'AFKO_WO_Basic_End_Date', 'AFKO_WO_Basic_Start_Date',
#        'AFKO_WO_Scheduled_Start_Date', 'AFKO_WO_Operation_ID',
#        'AFKO_WO_SubNetwork_ID', 'AUFK_WO_Number', 'AUFK_WO_Order_Type',
#        'AUFK_WO_Header_Description', 'AUFK_WO_Phase_Order_Created',
#        'AUFK_WO_Phase_Order_Released', 'AUFK_WO_Object_Number',
#        'AUFK_WO_Original_Deadline', 'AUFK_WO_Latest_Allowed_Finish_Date',
#        'AUFK_WO_Earliest_Allowed_Start_Date'],
#       dtype='object')

# %% [markdown]
# #### Merge df_work_order_merged and notifications

# %%
df_work_order_merged = df_work_order_merged.merge(notif_processed_df, how = 'left', left_on = ['AFIH_WO_Notification_Number'], right_on = ['NOTIF_Number'])

print(df_work_order_merged)
# Out:
#        AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 0          2300009145                3                             2558055
# 1          2400352096                A                             2610303
# 2          2100114335                3                             2571638
# 3          2100114433                3                             2604131
# 4          2800031347                2                             2529524
# ...               ...              ...                                 ...
# 121025     2100087418                4                             2273323
# 121026     2100086200                2                             2260911
# 121027     2100086201                2                             2260913
# 121028     2800024552                3                             2260977
# 121029     2900000760                3                             2261013
#
#        AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 0                             A                   MIN        10001172
# 1                             A                   INP        10001416
# 2                             A                   MMS        10001033
# 3                             A                   MFM        10001039
# 4                             A                   MFM        10001265
# ...                         ...                   ...             ...
# 121025                        A                   MFM        10001127
# 121026                        A                   MEL        10001122
# 121027                        A                   MEL        10001122
# 121028                        A                   CON        10001026
# 121029                        A                   WLD        10001372
#
#        AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 0                                NaN                           572308
# 1                        DKGO-PVI128                           580945
# 2                                NaN                           578916
# 3                                NaN                           579923
# 4                                NaN                                0
# ...                              ...                              ...
# 121025                           NaN                           448492
# 121026                           NaN                           442857
# 121027                           NaN                           442858
# 121028                           NaN                                0
# 121029                           NaN                           442897
#
#        AFIH_WO_Revision AFIH_WO_Activity_Type  ...  AUFK_WO_Number  \
# 0                   NaN                    SO  ...      2300009145
# 1                  NOSD                    RO  ...      2400352096
# 2                   NaN                    BK  ...      2100114335
# 3                   NaN                    BK  ...      2100114433
# 4                   NaN                    MD  ...             NaN
# ...                 ...                   ...  ...             ...
# 121025             NOSD                    PC  ...      2100087418
# 121026             NOSD                    BK  ...      2100086200
# 121027             NOSD                    BK  ...      2100086201
# 121028              NaN                    MD  ...      2800024552
# 121029              NaN                    SP  ...             NaN
#
#        AUFK_WO_Order_Type                AUFK_WO_Header_Description  \
# 0                     WRO         F83 Enable comm to new HMI serves
# 1                     WPM            PVI Intermediate - GOFD-E-4202
# 2                     WDF           TEC Crane - Key cylinder defect
# 3                     WDF  TEE-2-FLS-040-8652-AD-U - Weld Corrosion
# 4                     NaN                                       NaN
# ...                   ...                                       ...
# 121025                WDF  ANOCR DFB - Repair and Paint Diagonal Br
# 121026                WDF    Troubleshoot Firedamper DFGA-FD-123031
# 121027                WDF    Troubleshoot Firedamper DFGA-FD-130231
# 121028                WCC  TE-N1-5.3.12A install 12" J-Tube support
# 121029                NaN                                       NaN
#
#         AUFK_WO_Phase_Order_Created  AUFK_WO_Phase_Order_Released  \
# 0                                 X                           NaN
# 1                                 X                           NaN
# 2                                 X                           NaN
# 3                                 X                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 121025                          NaN                           NaN
# 121026                          NaN                           NaN
# 121027                          NaN                           NaN
# 121028                          NaN                           NaN
# 121029                          NaN                           NaN
#
#         AUFK_WO_Object_Number AUFK_WO_Original_Deadline  \
# 0              OR002300009145                20241201.0
# 1              OR002400352096                20251231.0
# 2              OR002100114335                20241209.0
# 3              OR002100114433                20241210.0
# 4                         NaN                       NaN
# ...                       ...                       ...
# 121025         OR002100087418                20251231.0
# 121026         OR002100086200                20230617.0
# 121027         OR002100086201                20230617.0
# 121028         OR002800024552                       0.0
# 121029                    NaN                       NaN
#
#        AUFK_WO_Latest_Allowed_Finish_Date AUFK_WO_Earliest_Allowed_Start_Date  \
# 0                              20241201.0                          20240719.0
# 1                              20251231.0                          20251019.0
# 2                              20241209.0                          20240727.0
# 3                              20241210.0                          20240728.0
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 121025                         20251231.0                          20230911.0
# 121026                         20230617.0                          20230503.0
# 121027                         20230617.0                          20230503.0
# 121028                                0.0                                 0.0
# 121029                                NaN                                 NaN
#
#                                            NOTIF_Row_Text
# 0                                                     NaN
# 1                                                     NaN
# 2        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 3        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 4                                                     NaN
# ...                                                   ...
# 121025   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121026   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121027   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121028                                                NaN
# 121029                                                NaN
#
# [121030 rows x 27 columns]

# %% [markdown]
# #### Merge df_work_order_merged and QMEL

# %%
df_work_order_merged = df_work_order_merged.merge(qmel_df, how = 'left', left_on = ['AFIH_WO_Notification_Number'], right_on = ['QMEL_Notification_Number'])

print(df_work_order_merged)
# Out:
#        AFIH_WO_Number AFIH_WO_Priority  AFIH_WO_Functional_Location_Number  \
# 0          2300009145                3                             2558055
# 1          2400352096                A                             2610303
# 2          2100114335                3                             2571638
# 3          2100114433                3                             2604131
# 4          2800031347                2                             2529524
# ...               ...              ...                                 ...
# 121025     2100087418                4                             2273323
# 121026     2100086200                2                             2260911
# 121027     2100086201                2                             2260913
# 121028     2800024552                3                             2260977
# 121029     2900000760                3                             2261013
#
#        AFIH_WO_System_Condition AFIH_WO_Planner_Group  AFIH_WO_WBS_ID  \
# 0                             A                   MIN        10001172
# 1                             A                   INP        10001416
# 2                             A                   MMS        10001033
# 3                             A                   MFM        10001039
# 4                             A                   MFM        10001265
# ...                         ...                   ...             ...
# 121025                        A                   MFM        10001127
# 121026                        A                   MEL        10001122
# 121027                        A                   MEL        10001122
# 121028                        A                   CON        10001026
# 121029                        A                   WLD        10001372
#
#        AFIH_WO_Maintenance_Plan_Name  AFIH_WO_Plan_Maintenance_Number  \
# 0                                NaN                           572308
# 1                        DKGO-PVI128                           580945
# 2                                NaN                           578916
# 3                                NaN                           579923
# 4                                NaN                                0
# ...                              ...                              ...
# 121025                           NaN                           448492
# 121026                           NaN                           442857
# 121027                           NaN                           442858
# 121028                           NaN                                0
# 121029                           NaN                           442897
#
#        AFIH_WO_Revision AFIH_WO_Activity_Type  ...  \
# 0                   NaN                    SO  ...
# 1                  NOSD                    RO  ...
# 2                   NaN                    BK  ...
# 3                   NaN                    BK  ...
# 4                   NaN                    MD  ...
# ...                 ...                   ...  ...
# 121025             NOSD                    PC  ...
# 121026             NOSD                    BK  ...
# 121027             NOSD                    BK  ...
# 121028              NaN                    MD  ...
# 121029              NaN                    SP  ...
#
#         AUFK_WO_Phase_Order_Created AUFK_WO_Phase_Order_Released  \
# 0                                 X                          NaN
# 1                                 X                          NaN
# 2                                 X                          NaN
# 3                                 X                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 121025                          NaN                          NaN
# 121026                          NaN                          NaN
# 121027                          NaN                          NaN
# 121028                          NaN                          NaN
# 121029                          NaN                          NaN
#
#         AUFK_WO_Object_Number  AUFK_WO_Original_Deadline  \
# 0              OR002300009145                 20241201.0
# 1              OR002400352096                 20251231.0
# 2              OR002100114335                 20241209.0
# 3              OR002100114433                 20241210.0
# 4                         NaN                        NaN
# ...                       ...                        ...
# 121025         OR002100087418                 20251231.0
# 121026         OR002100086200                 20230617.0
# 121027         OR002100086201                 20230617.0
# 121028         OR002800024552                        0.0
# 121029                    NaN                        NaN
#
#         AUFK_WO_Latest_Allowed_Finish_Date  \
# 0                               20241201.0
# 1                               20251231.0
# 2                               20241209.0
# 3                               20241210.0
# 4                                      NaN
# ...                                    ...
# 121025                          20251231.0
# 121026                          20230617.0
# 121027                          20230617.0
# 121028                                 0.0
# 121029                                 NaN
#
#         AUFK_WO_Earliest_Allowed_Start_Date  \
# 0                                20240719.0
# 1                                20251019.0
# 2                                20240727.0
# 3                                20240728.0
# 4                                       NaN
# ...                                     ...
# 121025                           20230911.0
# 121026                           20230503.0
# 121027                           20230503.0
# 121028                                  0.0
# 121029                                  NaN
#
#                                            NOTIF_Row_Text  \
# 0                                                     NaN
# 1                                                     NaN
# 2        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 3        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 4                                                     NaN
# ...                                                   ...
# 121025   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121026   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121027   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121028                                                NaN
# 121029                                                NaN
#
#        QMEL_Notification_Number QMEL_Notification_Created  \
# 0                  1.300012e+09                20240604.0
# 1                  1.400367e+09                20240620.0
# 2                  1.100152e+09                20240612.0
# 3                  1.100152e+09                20240613.0
# 4                           NaN                       NaN
# ...                         ...                       ...
# 121025             1.500006e+09                20230315.0
# 121026             1.100113e+09                20230226.0
# 121027             1.100113e+09                20230226.0
# 121028                      NaN                       NaN
# 121029             1.200021e+09                20230227.0
#
#        QMEL_Malfunction_Started
# 0                    20240604.0
# 1                    20240620.0
# 2                    20240612.0
# 3                    20240613.0
# 4                           NaN
# ...                         ...
# 121025               20230315.0
# 121026               20230226.0
# 121027               20230226.0
# 121028                      NaN
# 121029               20230227.0
#
# [121030 rows x 30 columns]

# %% [markdown]
# #### Filter and Rename columns to get the final Work Orders merge
#
# Columns kept:
# * AFIH_WO_Number -> WO_Number
# * AFIH_WO_Priority -> WO_Priority
# * AFIH_WO_Functional_Location_Number -> WO_Functional_Location_Number
# * AFIH_WO_Plan_Maintenance_Number -> WO_Plan_Maintenance_Number
# * AFIH_WO_Planner_Group -> WO_Planner_Group
# * AFIH_WO_WBS_ID -> WO_WBS_ID
# * AFIH_WO_Revision -> WO_Revision
# * AFIH_WO_Activity_Type -> WO_Activity_Type
# * AFKO_WO_Scheduled_Start_Date -> WO_Scheduled_Start_Date
# * AFKO_WO_Operation_ID -> WO_Operation_ID
# * AUFK_WO_Order_Type -> WO_Order_Type
# * AUFK_WO_Header_Description -> WO_Header_Description
# * AUFK_WO_Phase_Order_Created -> WO_Phase_Order_Created
# * AUFK_WO_Phase_Order_Released -> WO_Phase_Order_Released
# * AUFK_WO_Object_Number -> WO_Status_ID
# * AUFK_WO_Original_Deadline -> WO_Original_Deadline
# * AFIH_WO_Notification_Number -> WO_Notification_Number
# * NOTIF_Row_Text -> WO_Notification
# * QMEL_Malfunction_Started -> WO_Notification_Malfunction_Started
# * QMEL_Notification_Created -> WO_Notification_Created
# * AFIH_WO_Maintenance_Plan_Name -> WO_Maintenance_Plan_Name
# * AFIH_WO_System_Condition -> WO_System_Condition
# * AFKO_WO_Basic_Start_Date -> WO_Basic_Start_Date
# * AFKO_WO_Basic_End_Date -> WO_Basic_End_Date
# * AUFK_WO_Earliest_Allowed_Start_Date -> WO_Earliest_Allowed_Start_Date
# * AUFK_WO_Latest_Allowed_Finish_Date -> WO_Latest_Allowed_Finish_Date
# * AFKO_WO_SubNetwork_ID -> WO_SubNetwork_ID

# %%
# drop useless columns
df_work_order_merged = df_work_order_merged[["AFIH_WO_Number", "AFIH_WO_Priority", "AFIH_WO_Functional_Location_Number", "AFIH_WO_Plan_Maintenance_Number",
                                             "AFIH_WO_Planner_Group", "AFIH_WO_WBS_ID", "AFIH_WO_Revision", "AFIH_WO_Activity_Type", "AFKO_WO_Scheduled_Start_Date", 
                                             "AFKO_WO_Operation_ID", "AUFK_WO_Order_Type", "AUFK_WO_Header_Description", "AUFK_WO_Phase_Order_Created", 
                                             "AUFK_WO_Phase_Order_Released", "AUFK_WO_Object_Number", "AUFK_WO_Original_Deadline", "AFIH_WO_Notification_Number", 
                                             "QMEL_Malfunction_Started", "QMEL_Notification_Created", "NOTIF_Row_Text", "AFIH_WO_Maintenance_Plan_Name", "AFIH_WO_System_Condition",
                                             "AFKO_WO_Basic_Start_Date", "AFKO_WO_Basic_End_Date", "AUFK_WO_Earliest_Allowed_Start_Date", "AUFK_WO_Latest_Allowed_Finish_Date", 
                                             "AFKO_WO_SubNetwork_ID"
                                             ]]

# rename columns
df_work_order_merged.rename(inplace = True, columns = {
    "AFIH_WO_Number": "WO_Number", 
    "AFIH_WO_Priority": "WO_Priority", 
    "AFIH_WO_Functional_Location_Number": "WO_Functional_Location_Number",
    "AFIH_WO_Plan_Maintenance_Number": "WO_Plan_Maintenance_Number",
    "AFIH_WO_Planner_Group": "WO_Planner_Group",
    "AFIH_WO_WBS_ID": "WO_WBS_ID",
    "AFIH_WO_Revision": "WO_Revision",
    "AFIH_WO_Activity_Type": "WO_Activity_Type",
    "AFKO_WO_Scheduled_Start_Date": "WO_Scheduled_Start_Date",
    "AFKO_WO_Operation_ID": "WO_Operation_ID",
    "AUFK_WO_Order_Type": "WO_Order_Type",
    "AUFK_WO_Header_Description": "WO_Header_Description",
    "AUFK_WO_Phase_Order_Created": "WO_Phase_Order_Created",
    "AUFK_WO_Phase_Order_Released": "WO_Phase_Order_Released",
    "AUFK_WO_Object_Number": "WO_Status_ID",
    "AUFK_WO_Original_Deadline": "WO_Original_Deadline",
    "AFIH_WO_Notification_Number": "WO_Notification_Number",
    "QMEL_Malfunction_Started": "WO_Notification_Malfunction_Started",
    "QMEL_Notification_Created": "WO_Notification_Created",
    "AFIH_WO_Maintenance_Plan_Name": "WO_Maintenance_Plan_Name",
    "AFIH_WO_System_Condition": "WO_System_Condition",
    "NOTIF_Row_Text": "WO_Notification",
    "AFKO_WO_Basic_Start_Date": "WO_Basic_Start_Date",
    "AFKO_WO_Basic_End_Date": "WO_Basic_End_Date",
    "AUFK_WO_Earliest_Allowed_Start_Date": "WO_Earliest_Allowed_Start_Date",
    "AUFK_WO_Latest_Allowed_Finish_Date": "WO_Latest_Allowed_Finish_Date",
    "AFKO_WO_SubNetwork_ID": "WO_SubNetwork_ID"
})

print(df_work_order_merged)
# Out:
#          WO_Number WO_Priority  WO_Functional_Location_Number  \
# 0       2300009145           3                        2558055
# 1       2400352096           A                        2610303
# 2       2100114335           3                        2571638
# 3       2100114433           3                        2604131
# 4       2800031347           2                        2529524
# ...            ...         ...                            ...
# 121025  2100087418           4                        2273323
# 121026  2100086200           2                        2260911
# 121027  2100086201           2                        2260913
# 121028  2800024552           3                        2260977
# 121029  2900000760           3                        2261013
#
#         WO_Plan_Maintenance_Number WO_Planner_Group  WO_WBS_ID WO_Revision  \
# 0                           572308              MIN   10001172         NaN
# 1                           580945              INP   10001416        NOSD
# 2                           578916              MMS   10001033         NaN
# 3                           579923              MFM   10001039         NaN
# 4                                0              MFM   10001265         NaN
# ...                            ...              ...        ...         ...
# 121025                      448492              MFM   10001127        NOSD
# 121026                      442857              MEL   10001122        NOSD
# 121027                      442858              MEL   10001122        NOSD
# 121028                           0              CON   10001026         NaN
# 121029                      442897              WLD   10001372         NaN
#
#        WO_Activity_Type  WO_Scheduled_Start_Date  WO_Operation_ID  ...  \
# 0                    SO               20251019.0     1.000668e+09  ...
# 1                    RO               20251019.0     1.000678e+09  ...
# 2                    BK               20240727.0     1.000675e+09  ...
# 3                    BK               20240728.0     1.000677e+09  ...
# 4                    MD               20221001.0     1.000653e+09  ...
# ...                 ...                      ...              ...  ...
# 121025               PC               20230911.0     1.000512e+09  ...
# 121026               BK               20231120.0     1.000504e+09  ...
# 121027               BK               20231218.0     1.000504e+09  ...
# 121028               MD               20230501.0     1.000505e+09  ...
# 121029               SP               20230413.0     1.000505e+09  ...
#
#        WO_Notification_Malfunction_Started WO_Notification_Created  \
# 0                               20240604.0              20240604.0
# 1                               20240620.0              20240620.0
# 2                               20240612.0              20240612.0
# 3                               20240613.0              20240613.0
# 4                                      NaN                     NaN
# ...                                    ...                     ...
# 121025                          20230315.0              20230315.0
# 121026                          20230226.0              20230226.0
# 121027                          20230226.0              20230226.0
# 121028                                 NaN                     NaN
# 121029                          20230227.0              20230227.0
#
#                                           WO_Notification  \
# 0                                                     NaN
# 1                                                     NaN
# 2        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 3        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 4                                                     NaN
# ...                                                   ...
# 121025   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121026   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121027   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121028                                                NaN
# 121029                                                NaN
#
#        WO_Maintenance_Plan_Name WO_System_Condition  WO_Basic_Start_Date  \
# 0                           NaN                   A           20251019.0
# 1                   DKGO-PVI128                   A           20251019.0
# 2                           NaN                   A           20240727.0
# 3                           NaN                   A           20240728.0
# 4                           NaN                   A           20221001.0
# ...                         ...                 ...                  ...
# 121025                      NaN                   A           20230911.0
# 121026                      NaN                   A           20231120.0
# 121027                      NaN                   A           20231218.0
# 121028                      NaN                   A           20230501.0
# 121029                      NaN                   A           20230413.0
#
#         WO_Basic_End_Date  WO_Earliest_Allowed_Start_Date  \
# 0              20251020.0                      20240719.0
# 1              20251028.0                      20251019.0
# 2              20240727.0                      20240727.0
# 3              20240728.0                      20240728.0
# 4              20221001.0                             NaN
# ...                   ...                             ...
# 121025         20230918.0                      20230911.0
# 121026         20231125.0                      20230503.0
# 121027         20231219.0                      20230503.0
# 121028         20230504.0                             0.0
# 121029         20230413.0                             NaN
#
#         WO_Latest_Allowed_Finish_Date WO_SubNetwork_ID
# 0                          20241201.0              NaN
# 1                          20251231.0              NaN
# 2                          20241209.0              NaN
# 3                          20241210.0              NaN
# 4                                 NaN              NaN
# ...                               ...              ...
# 121025                     20251231.0              NaN
# 121026                     20230617.0              NaN
# 121027                     20230617.0              NaN
# 121028                            0.0       99000027.0
# 121029                            NaN              NaN
#
# [121030 rows x 27 columns]

# %% [markdown]
# ### save data into a csv file

# %%
write_mid_level_csv_file(df_work_order_merged, "work_orders")

# %% [markdown]
# ## 5. Secondary functional locations
#
# It's possible to perform the secondary functional locations only after the work order processing to avoid loading the same table multiple times
#
# Table:
# * OBJK

# %% [markdown]
# ### Read OBJK data

# %%
# Needed columns
objk_columns = {
    'OBKNR': 'PM_Object_Number',
    'SORTF': 'PM_Object_Sorting',
    'OBJVW': 'PM_Object_Usage',
    'ILOAN': 'PM_Functional_Location'
}

# Read AFIH table
objk_df = read_csv_file("OBJK", objk_columns)

# Filter on NaN function location
objk_df.dropna(subset = ["PM_Functional_Location"], inplace = True)
objk_df.reset_index(inplace = True, drop = True)

print(objk_df)
# Out:
#          PM_Object_Number  PM_Functional_Location PM_Object_Sorting  \
# 0                  572073               2127560.0              0020
# 1                  572084               2126675.0              0010
# 2                  572084               2127974.0              0020
# 3                  572084               2125953.0              0030
# 4                  572084               2125961.0              0040
# ...                   ...                     ...               ...
# 1468164            598358               2608974.0               NaN
# 1468165            598367               2608974.0               NaN
# 1468166            598271               2609038.0               NaN
# 1468167            598377               2609038.0               NaN
# 1468168            598270               2609038.0               NaN
#
#         PM_Object_Usage
# 0                     A
# 1                     A
# 2                     A
# 3                     A
# 4                     A
# ...                 ...
# 1468164               W
# 1468165               W
# 1468166               W
# 1468167               W
# 1468168               W
#
# [1468169 rows x 4 columns]
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\1343571107.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/E1P_010_' + file_name + '.csv', delimiter = ';', usecols = columns_dict.keys())

# %% [markdown]
# ### Save data

# %%
write_mid_level_csv_file(objk_df, 'secondary_locations')

# %%
print(objk_df[objk_df["PM_Object_Number"] == 572084])
# Out:
#    PM_Object_Number  PM_Functional_Location PM_Object_Sorting PM_Object_Usage
# 1            572084               2126675.0              0010               A
# 2            572084               2127974.0              0020               A
# 3            572084               2125953.0              0030               A
# 4            572084               2125961.0              0040               A
# 5            572084               2126363.0              0050               A
# 6            572084               2126274.0              0060               A

# %% [markdown]
# ## 6. Operations Tables
#
# Tables:
# * AFVC
# * AFVV

# %% [markdown]
# ### Read data

# %% [markdown]
# #### Read AFVC data

# %%
# needed columns
afvc_columns = {
    "ARBID": 'AFVC_WBS_ID',
    "AUFPL": 'AFVC_Operation_Routing_Number',
    "VORNR": "AFVC_Operation_Activity_Number",
    "APLZL": 'AFVC_Operation_Counter',
    "ANZZL": 'AFVC_Workers_Number',
    "ABLAD": "AFVC_Scheduled_Work",
    "OBJNR": "AFVC_Status_ID",
    "LTXA1": "AFVC_Operation_Short_Text"
}

# read the df
afvc_df = read_csv_file("AFVC_V1", afvc_columns)

# %%
print(afvc_df)
# Out:
#         AFVC_Operation_Routing_Number  AFVC_Operation_Counter  \
# 0                          1000589075                       3
# 1                          1000589075                       4
# 2                          1000589075                       5
# 3                          1000589075                       6
# 4                          1000589075                       7
# ...                               ...                     ...
# 518445                     1000515357                       1
# 518446                     1000515358                       1
# 518447                     1000515359                       1
# 518448                     1000515360                       1
# 518449                     1000197463                      13
#
#         AFVC_Operation_Activity_Number  AFVC_WBS_ID  \
# 0                                   30     10001079
# 1                                   40     10001080
# 2                                   50     10001081
# 3                                   60     10001080
# 4                                   70     10001079
# ...                                ...          ...
# 518445                              10     10001440
# 518446                              10     10001168
# 518447                            9000            0
# 518448                              10     10001080
# 518449                             130     10001566
#
#                    AFVC_Operation_Short_Text  AFVC_Workers_Number  \
# 0       Actuator isolations & disconnections                    1
# 1         Ex-service ESDV-41017 & FO removal                    2
# 2                         Rigging assistance                    2
# 3           New ESDV-41017 & FO installation                    2
# 4        Actuator connections / Unit testing                    1
# ...                                      ...                  ...
# 518445   Caisson flange failed/missing bolts                    0
# 518446          HBA23 - HCV--30234 int. leak                    0
# 518447  Inspection by material specification                    0
# 518448                   HWAA-TCV-34043 leak                    0
# 518449                    Stock PSV Offshore                    0
#
#               AFVC_Status_ID AFVC_Scheduled_Work
# 0       OV100058907500000003                 NaN
# 1       OV100058907500000004                 NaN
# 2       OV100058907500000005                 NaN
# 3       OV100058907500000006                 NaN
# 4       OV100058907500000007                 NaN
# ...                      ...                 ...
# 518445  OV100051535700000001                 NaN
# 518446  OV100051535800000001                 NaN
# 518447                   NaN                 NaN
# 518448  OV100051536000000001                 NaN
# 518449  OV100019746300000013                 NaN
#
# [518450 rows x 8 columns]

# %% [markdown]
# #### Read AFVV data

# %%
# needed columns
afvv_columns = {
    "AUFPL": 'AFVV_Operation_Routing_Number',
    "APLZL": 'AFVV_Operation_Counter',
    "ARBEI": 'AFVV_Planned_Work',
    "ISMNW": 'AFVV_Actual_Work',
    "FSSBD": 'AFVV_Work_Start_Date',
    "FSSBZ": 'AFVV_Work_Start_Time',
    "FSSAD": 'AFVV_Work_End_Date',
    "FSSAZ": 'AFVV_Work_End_Time'
}

# read the df
afvv_df = read_csv_file("AFVV_V1", afvv_columns)

# %%
print(afvv_df)
# Out:
#         AFVV_Operation_Routing_Number  AFVV_Operation_Counter  \
# 0                          1000589075                       3
# 1                          1000589075                       4
# 2                          1000589075                       5
# 3                          1000589075                       6
# 4                          1000589075                       7
# ...                               ...                     ...
# 518445                     1000197463                      13
# 518446                     1000515357                       1
# 518447                     1000515358                       1
# 518448                     1000515359                       1
# 518449                     1000515360                       1
#
#         AFVV_Planned_Work  AFVV_Actual_Work  AFVV_Work_Start_Date  \
# 0                     2.0               0.0              20241010
# 1                     6.0               0.0              20241011
# 2                     6.0               0.0              20241011
# 3                    10.0               0.0              20241011
# 4                     3.0               0.0              20241012
# ...                   ...               ...                   ...
# 518445                0.0               0.0              20230515
# 518446                0.0               0.0              20230509
# 518447                0.0               0.0              20240830
# 518448                0.0               0.0                     0
# 518449                0.0               0.0              20230330
#
#         AFVV_Work_Start_Time  AFVV_Work_End_Date  AFVV_Work_End_Time
# 0                     182206            20241011               85341
# 1                      85341            20241011              124103
# 2                      85341            20241011              124103
# 3                     124103            20241011              190000
# 4                      70000            20241012              104722
# ...                      ...                 ...                 ...
# 518445                 94103            20230515               94103
# 518446                144500            20230509              144500
# 518447                115800            20240830              115800
# 518448                     0                   0                   0
# 518449                 91400            20230330               91400
#
# [518450 rows x 8 columns]

# %% [markdown]
# ### Merge AFVC and AFVV

# %%
df_operations_merged = afvc_df.merge(afvv_df, how = 'left', left_on = ["AFVC_Operation_Routing_Number", "AFVC_Operation_Counter"], right_on = ["AFVV_Operation_Routing_Number", "AFVV_Operation_Counter"])

print(df_operations_merged)
# Out:
#         AFVC_Operation_Routing_Number  AFVC_Operation_Counter  \
# 0                          1000589075                       3
# 1                          1000589075                       4
# 2                          1000589075                       5
# 3                          1000589075                       6
# 4                          1000589075                       7
# ...                               ...                     ...
# 518445                     1000515357                       1
# 518446                     1000515358                       1
# 518447                     1000515359                       1
# 518448                     1000515360                       1
# 518449                     1000197463                      13
#
#         AFVC_Operation_Activity_Number  AFVC_WBS_ID  \
# 0                                   30     10001079
# 1                                   40     10001080
# 2                                   50     10001081
# 3                                   60     10001080
# 4                                   70     10001079
# ...                                ...          ...
# 518445                              10     10001440
# 518446                              10     10001168
# 518447                            9000            0
# 518448                              10     10001080
# 518449                             130     10001566
#
#                    AFVC_Operation_Short_Text  AFVC_Workers_Number  \
# 0       Actuator isolations & disconnections                    1
# 1         Ex-service ESDV-41017 & FO removal                    2
# 2                         Rigging assistance                    2
# 3           New ESDV-41017 & FO installation                    2
# 4        Actuator connections / Unit testing                    1
# ...                                      ...                  ...
# 518445   Caisson flange failed/missing bolts                    0
# 518446          HBA23 - HCV--30234 int. leak                    0
# 518447  Inspection by material specification                    0
# 518448                   HWAA-TCV-34043 leak                    0
# 518449                    Stock PSV Offshore                    0
#
#               AFVC_Status_ID AFVC_Scheduled_Work  \
# 0       OV100058907500000003                 NaN
# 1       OV100058907500000004                 NaN
# 2       OV100058907500000005                 NaN
# 3       OV100058907500000006                 NaN
# 4       OV100058907500000007                 NaN
# ...                      ...                 ...
# 518445  OV100051535700000001                 NaN
# 518446  OV100051535800000001                 NaN
# 518447                   NaN                 NaN
# 518448  OV100051536000000001                 NaN
# 518449  OV100019746300000013                 NaN
#
#         AFVV_Operation_Routing_Number  AFVV_Operation_Counter  \
# 0                          1000589075                       3
# 1                          1000589075                       4
# 2                          1000589075                       5
# 3                          1000589075                       6
# 4                          1000589075                       7
# ...                               ...                     ...
# 518445                     1000515357                       1
# 518446                     1000515358                       1
# 518447                     1000515359                       1
# 518448                     1000515360                       1
# 518449                     1000197463                      13
#
#         AFVV_Planned_Work  AFVV_Actual_Work  AFVV_Work_Start_Date  \
# 0                     2.0               0.0              20241010
# 1                     6.0               0.0              20241011
# 2                     6.0               0.0              20241011
# 3                    10.0               0.0              20241011
# 4                     3.0               0.0              20241012
# ...                   ...               ...                   ...
# 518445                0.0               0.0              20230509
# 518446                0.0               0.0              20240830
# 518447                0.0               0.0                     0
# 518448                0.0               0.0              20230330
# 518449                0.0               0.0              20230515
#
#         AFVV_Work_Start_Time  AFVV_Work_End_Date  AFVV_Work_End_Time
# 0                     182206            20241011               85341
# 1                      85341            20241011              124103
# 2                      85341            20241011              124103
# 3                     124103            20241011              190000
# 4                      70000            20241012              104722
# ...                      ...                 ...                 ...
# 518445                144500            20230509              144500
# 518446                115800            20240830              115800
# 518447                     0                   0                   0
# 518448                 91400            20230330               91400
# 518449                 94103            20230515               94103
#
# [518450 rows x 16 columns]

# %%
print(df_operations_merged[df_operations_merged["AFVC_Operation_Routing_Number"] == 1000126414])
# Out:
#         AFVC_Operation_Routing_Number  AFVC_Operation_Counter  \
# 58551                      1000126414                       7
# 101912                     1000126414                       1
# 101913                     1000126414                       2
# 101914                     1000126414                       3
# 101915                     1000126414                       4
# 101916                     1000126414                       5
# 101917                     1000126414                       6
#
#         AFVC_Operation_Activity_Number  AFVC_WBS_ID  \
# 58551                               40     10001289
# 101912                              10     10001293
# 101913                              11     10001289
# 101914                              12     10001288
# 101915                              20     10001289
# 101916                              25     10001293
# 101917                              30     10001324
#
#            AFVC_Operation_Short_Text  AFVC_Workers_Number  \
# 58551   Order Mat. to WCC-2800006761                    1
# 101912               Remove supports                    1
# 101913           Mechanical cleaning                    1
# 101914                           NDT                    1
# 101915  Painting according to ID:253                    3
# 101916                Mount supports                    1
# 101917             Check of painting                    1
#
#               AFVC_Status_ID AFVC_Scheduled_Work  \
# 58551   OV100012641400000007                 NaN
# 101912  OV100012641400000001                 NaN
# 101913  OV100012641400000002                 NaN
# 101914  OV100012641400000003                 NaN
# 101915  OV100012641400000004                 NaN
# 101916  OV100012641400000005                 NaN
# 101917  OV100012641400000006                CONS
#
#         AFVV_Operation_Routing_Number  AFVV_Operation_Counter  \
# 58551                      1000126414                       7
# 101912                     1000126414                       1
# 101913                     1000126414                       2
# 101914                     1000126414                       3
# 101915                     1000126414                       4
# 101916                     1000126414                       5
# 101917                     1000126414                       6
#
#         AFVV_Planned_Work  AFVV_Actual_Work  AFVV_Work_Start_Date  \
# 58551                 1.0               0.0              20200717
# 101912                2.0               2.0              20200717
# 101913                3.0               3.0              20200717
# 101914                1.3               0.0              20200717
# 101915               15.0              10.0              20200724
# 101916                2.0               0.0              20200808
# 101917                2.0               0.0              20200717
#
#         AFVV_Work_Start_Time  AFVV_Work_End_Date  AFVV_Work_End_Time
# 58551                  70000            20200717               81845
# 101912                 70000            20200717               70000
# 101913                 70000            20200717               70000
# 101914                 70000            20200717               83832
# 101915                220000            20200725               70000
# 101916                 60000            20200808               93730
# 101917                 70000            20200717               93135

# %% [markdown]
# ### Filter and Rename columns to get the final Operations merge
#
# Columns kept:
# * AFVC_Operation_Routing_Number -> WO_OPR_Routing_Number
# * AFVC_Operation_Counter -> WO_OPR_Counter
# * AFVC_Operation_Activity_Number -> OPR_Activity_Number
# * AFVC_WBS_ID -> WO_OPR_WBS_ID
# * AFVC_Workers_Number -> WO_OPR_Workers_Numbers
# * AFVV_Planned_Work -> OPR_Planned_Work
# * AFVV_Actual_Work -> OPR_Actual_Work
# * AFVV_Work_Start_Date -> OPR_Start_Date
# * AFVV_Work_Start_Time -> OPR_Start_Time
# * AFVV_Work_End_Date -> OPR_End_Date
# * AFVV_Work_End_Time -> OPR_End_Time
# * AFVC_Scheduled_Work -> OPR_Scheduled_Work
# * AFVC_Status_ID -> OPR_Status_ID
# * AFVC_Operation_Short_Text -> OPR_Description

# %%
# drop useless columns
df_operations_merged = df_operations_merged[["AFVC_Operation_Routing_Number", "AFVC_Operation_Counter", "AFVC_WBS_ID", 
                                             "AFVC_Workers_Number", "AFVV_Planned_Work", "AFVV_Actual_Work", "AFVV_Work_Start_Date", "AFVV_Work_Start_Time",
                                             "AFVV_Work_End_Date", "AFVV_Work_End_Time", "AFVC_Scheduled_Work", "AFVC_Operation_Short_Text", 
                                             "AFVC_Operation_Activity_Number", "AFVC_Status_ID"
                                            ]]

# rename columns
df_operations_merged.rename(inplace = True, columns = {
    "AFVC_Operation_Routing_Number": "OPR_Routing_Number", 
    "AFVC_Operation_Counter": "OPR_Counter", 
    "AFVC_Operation_Activity_Number": "OPR_Activity_Number",
    "AFVC_WBS_ID": "OPR_WBS_ID",
    "AFVC_Workers_Number": "OPR_Workers_Numbers",
    "AFVV_Planned_Work": "OPR_Planned_Work",
    "AFVV_Actual_Work": "OPR_Actual_Work",
    "AFVV_Work_Start_Date": "OPR_Start_Date",
    "AFVV_Work_Start_Time": "OPR_Start_Time",
    "AFVV_Work_End_Date": "OPR_End_Date",
    "AFVV_Work_End_Time": "OPR_End_Time",
    "AFVC_Scheduled_Work": "OPR_Scheduled_Work",
    "AFVC_Status_ID": "OPR_Status_ID",
    "AFVC_Operation_Short_Text": "OPR_Description",
})


print(df_operations_merged)
# Out:
#         OPR_Routing_Number  OPR_Counter  OPR_WBS_ID  OPR_Workers_Numbers  \
# 0               1000589075            3    10001079                    1
# 1               1000589075            4    10001080                    2
# 2               1000589075            5    10001081                    2
# 3               1000589075            6    10001080                    2
# 4               1000589075            7    10001079                    1
# ...                    ...          ...         ...                  ...
# 518445          1000515357            1    10001440                    0
# 518446          1000515358            1    10001168                    0
# 518447          1000515359            1           0                    0
# 518448          1000515360            1    10001080                    0
# 518449          1000197463           13    10001566                    0
#
#         OPR_Planned_Work  OPR_Actual_Work  OPR_Start_Date  OPR_Start_Time  \
# 0                    2.0              0.0        20241010          182206
# 1                    6.0              0.0        20241011           85341
# 2                    6.0              0.0        20241011           85341
# 3                   10.0              0.0        20241011          124103
# 4                    3.0              0.0        20241012           70000
# ...                  ...              ...             ...             ...
# 518445               0.0              0.0        20230509          144500
# 518446               0.0              0.0        20240830          115800
# 518447               0.0              0.0               0               0
# 518448               0.0              0.0        20230330           91400
# 518449               0.0              0.0        20230515           94103
#
#         OPR_End_Date  OPR_End_Time OPR_Scheduled_Work  \
# 0           20241011         85341                NaN
# 1           20241011        124103                NaN
# 2           20241011        124103                NaN
# 3           20241011        190000                NaN
# 4           20241012        104722                NaN
# ...              ...           ...                ...
# 518445      20230509        144500                NaN
# 518446      20240830        115800                NaN
# 518447             0             0                NaN
# 518448      20230330         91400                NaN
# 518449      20230515         94103                NaN
#
#                              OPR_Description  OPR_Activity_Number  \
# 0       Actuator isolations & disconnections                   30
# 1         Ex-service ESDV-41017 & FO removal                   40
# 2                         Rigging assistance                   50
# 3           New ESDV-41017 & FO installation                   60
# 4        Actuator connections / Unit testing                   70
# ...                                      ...                  ...
# 518445   Caisson flange failed/missing bolts                   10
# 518446          HBA23 - HCV--30234 int. leak                   10
# 518447  Inspection by material specification                 9000
# 518448                   HWAA-TCV-34043 leak                   10
# 518449                    Stock PSV Offshore                  130
#
#                OPR_Status_ID
# 0       OV100058907500000003
# 1       OV100058907500000004
# 2       OV100058907500000005
# 3       OV100058907500000006
# 4       OV100058907500000007
# ...                      ...
# 518445  OV100051535700000001
# 518446  OV100051535800000001
# 518447                   NaN
# 518448  OV100051536000000001
# 518449  OV100019746300000013
#
# [518450 rows x 14 columns]

# %%
write_mid_level_csv_file(df_operations_merged, "work_operations")

# %% [markdown]
# ## Functions to get all data related to one Work Order

# %% [markdown]
# ### Read mid csv files
#
# Simulates API getting its data from read csv files

# %%
def read_mid_csv_file(file_name):
    print("-----------------------------------")
    print("-----------------------------------")
    print("-----------------------------------")
    print("------ " + file_name + " ----------")
    print("\n")
    df = pd.read_csv('./data/mid_' + file_name + '.csv', delimiter = ',', index_col=0)
    print(df)
    return df

# Locations
functional_locations_df = read_mid_csv_file("functional_locations")
plan_maintenance_location_df = read_mid_csv_file("secondary_locations")
plan_maintenance_location_df["PM_Functional_Location"] = plan_maintenance_location_df["PM_Functional_Location"].astype(int)

# Work order
work_orders_df = read_mid_csv_file("work_orders")

# Operations
operations_df = read_mid_csv_file("work_operations")

# WBS
wbs_df = read_mid_csv_file("work_center")

# Status
wo_status_df = read_mid_csv_file("work_orders_status")
opr_status_df = read_mid_csv_file("operations_status")
# Out:
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ functional_locations ----------
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\859204161.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/mid_' + file_name + '.csv', delimiter = ',', index_col=0)
#         FLOC_Technical_ID    FLOC_Functional_ID  \
# 0                 2512161  ?0100000000000632852
# 1                 2512180  ?0100000000000634098
# 2                 1180579  ?0100000000000580069
# 3                 1180580  ?0100000000000580070
# 4                 1180581  ?0100000000000580071
# ...                   ...                   ...
# 489421            2668856  ?0100000000000646315
# 489422            2668874  ?0100000000000649833
# 489423            2668873  ?0100000000000649833
# 489424            2668907  ?0100000000000649698
# 489425            2668911  ?0100000000000733468
#
#                                  FLOC_Name ILOAN_Location_Room FLOC_Plant_Code
# 0                    HW /A /07/HWAA-P-5902                 NaN            DK30
# 1            HW /A /10/HEA06-MANUAL-VALVES                 NaN            DK30
# 2                 HD /A /23/HDAD-BDV-33035                 NaN            DK60
# 3                HD /A /23/HDAD-ESDV-33032                 NaN            DK60
# 4       HD /A /28/HDA-0.5-DP-041-0002-AS-U                 NaN            DK60
# ...                                    ...                 ...             ...
# 489421                  GO /B /78/GB-M-712                 NaN            DK80
# 489422                 GO /E /78/GEA-M-716                 NaN            DK80
# 489423                 GO /E /78/GEA-M-716                 NaN            DK80
# 489424               DF /G /54/DFGA-A-3590                 NaN            DK40
# 489425                               TE /H                 NaN            DK20
#
# [489426 rows x 5 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ secondary_locations ----------
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\859204161.py:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/mid_' + file_name + '.csv', delimiter = ',', index_col=0)
#          PM_Object_Number  PM_Functional_Location PM_Object_Sorting  \
# 0                  572073               2127560.0              0020
# 1                  572084               2126675.0              0010
# 2                  572084               2127974.0              0020
# 3                  572084               2125953.0              0030
# 4                  572084               2125961.0              0040
# ...                   ...                     ...               ...
# 1468164            598358               2608974.0               NaN
# 1468165            598367               2608974.0               NaN
# 1468166            598271               2609038.0               NaN
# 1468167            598377               2609038.0               NaN
# 1468168            598270               2609038.0               NaN
#
#         PM_Object_Usage
# 0                     A
# 1                     A
# 2                     A
# 3                     A
# 4                     A
# ...                 ...
# 1468164               W
# 1468165               W
# 1468166               W
# 1468167               W
# 1468168               W
#
# [1468169 rows x 4 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ work_orders ----------
# C:\Users\L0551542\AppData\Local\Temp\ipykernel_24412\859204161.py:7: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/mid_' + file_name + '.csv', delimiter = ',', index_col=0)
#          WO_Number WO_Priority  WO_Functional_Location_Number  \
# 0       2300009145           3                        2558055
# 1       2400352096           A                        2610303
# 2       2100114335           3                        2571638
# 3       2100114433           3                        2604131
# 4       2800031347           2                        2529524
# ...            ...         ...                            ...
# 121025  2100087418           4                        2273323
# 121026  2100086200           2                        2260911
# 121027  2100086201           2                        2260913
# 121028  2800024552           3                        2260977
# 121029  2900000760           3                        2261013
#
#         WO_Plan_Maintenance_Number WO_Planner_Group  WO_WBS_ID WO_Revision  \
# 0                           572308              MIN   10001172         NaN
# 1                           580945              INP   10001416        NOSD
# 2                           578916              MMS   10001033         NaN
# 3                           579923              MFM   10001039         NaN
# 4                                0              MFM   10001265         NaN
# ...                            ...              ...        ...         ...
# 121025                      448492              MFM   10001127        NOSD
# 121026                      442857              MEL   10001122        NOSD
# 121027                      442858              MEL   10001122        NOSD
# 121028                           0              CON   10001026         NaN
# 121029                      442897              WLD   10001372         NaN
#
#        WO_Activity_Type  WO_Scheduled_Start_Date  WO_Operation_ID  ...  \
# 0                    SO               20251019.0     1.000668e+09  ...
# 1                    RO               20251019.0     1.000678e+09  ...
# 2                    BK               20240727.0     1.000675e+09  ...
# 3                    BK               20240728.0     1.000677e+09  ...
# 4                    MD               20221001.0     1.000653e+09  ...
# ...                 ...                      ...              ...  ...
# 121025               PC               20230911.0     1.000512e+09  ...
# 121026               BK               20231120.0     1.000504e+09  ...
# 121027               BK               20231218.0     1.000504e+09  ...
# 121028               MD               20230501.0     1.000505e+09  ...
# 121029               SP               20230413.0     1.000505e+09  ...
#
#        WO_Notification_Malfunction_Started WO_Notification_Created  \
# 0                               20240604.0              20240604.0
# 1                               20240620.0              20240620.0
# 2                               20240612.0              20240612.0
# 3                               20240613.0              20240613.0
# 4                                      NaN                     NaN
# ...                                    ...                     ...
# 121025                          20230315.0              20230315.0
# 121026                          20230226.0              20230226.0
# 121027                          20230226.0              20230226.0
# 121028                                 NaN                     NaN
# 121029                          20230227.0              20230227.0
#
#                                           WO_Notification  \
# 0                                                     NaN
# 1                                                     NaN
# 2        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 3        DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 4                                                     NaN
# ...                                                   ...
# 121025   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121026   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121027   DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 121028                                                NaN
# 121029                                                NaN
#
#        WO_Maintenance_Plan_Name WO_System_Condition  WO_Basic_Start_Date  \
# 0                           NaN                   A           20251019.0
# 1                   DKGO-PVI128                   A           20251019.0
# 2                           NaN                   A           20240727.0
# 3                           NaN                   A           20240728.0
# 4                           NaN                   A           20221001.0
# ...                         ...                 ...                  ...
# 121025                      NaN                   A           20230911.0
# 121026                      NaN                   A           20231120.0
# 121027                      NaN                   A           20231218.0
# 121028                      NaN                   A           20230501.0
# 121029                      NaN                   A           20230413.0
#
#         WO_Basic_End_Date  WO_Earliest_Allowed_Start_Date  \
# 0              20251020.0                      20240719.0
# 1              20251028.0                      20251019.0
# 2              20240727.0                      20240727.0
# 3              20240728.0                      20240728.0
# 4              20221001.0                             NaN
# ...                   ...                             ...
# 121025         20230918.0                      20230911.0
# 121026         20231125.0                      20230503.0
# 121027         20231219.0                      20230503.0
# 121028         20230504.0                             0.0
# 121029         20230413.0                             NaN
#
#         WO_Latest_Allowed_Finish_Date WO_SubNetwork_ID
# 0                          20241201.0              NaN
# 1                          20251231.0              NaN
# 2                          20241209.0              NaN
# 3                          20241210.0              NaN
# 4                                 NaN              NaN
# ...                               ...              ...
# 121025                     20251231.0              NaN
# 121026                     20230617.0              NaN
# 121027                     20230617.0              NaN
# 121028                            0.0       99000027.0
# 121029                            NaN              NaN
#
# [121030 rows x 27 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ work_operations ----------
#
#
#         OPR_Routing_Number  OPR_Counter  OPR_WBS_ID  OPR_Workers_Numbers  \
# 0               1000589075            3    10001079                    1
# 1               1000589075            4    10001080                    2
# 2               1000589075            5    10001081                    2
# 3               1000589075            6    10001080                    2
# 4               1000589075            7    10001079                    1
# ...                    ...          ...         ...                  ...
# 518445          1000515357            1    10001440                    0
# 518446          1000515358            1    10001168                    0
# 518447          1000515359            1           0                    0
# 518448          1000515360            1    10001080                    0
# 518449          1000197463           13    10001566                    0
#
#         OPR_Planned_Work  OPR_Actual_Work  OPR_Start_Date  OPR_Start_Time  \
# 0                    2.0              0.0        20241010          182206
# 1                    6.0              0.0        20241011           85341
# 2                    6.0              0.0        20241011           85341
# 3                   10.0              0.0        20241011          124103
# 4                    3.0              0.0        20241012           70000
# ...                  ...              ...             ...             ...
# 518445               0.0              0.0        20230509          144500
# 518446               0.0              0.0        20240830          115800
# 518447               0.0              0.0               0               0
# 518448               0.0              0.0        20230330           91400
# 518449               0.0              0.0        20230515           94103
#
#         OPR_End_Date  OPR_End_Time OPR_Scheduled_Work  \
# 0           20241011         85341                NaN
# 1           20241011        124103                NaN
# 2           20241011        124103                NaN
# 3           20241011        190000                NaN
# 4           20241012        104722                NaN
# ...              ...           ...                ...
# 518445      20230509        144500                NaN
# 518446      20240830        115800                NaN
# 518447             0             0                NaN
# 518448      20230330         91400                NaN
# 518449      20230515         94103                NaN
#
#                              OPR_Description  OPR_Activity_Number  \
# 0       Actuator isolations & disconnections                   30
# 1         Ex-service ESDV-41017 & FO removal                   40
# 2                         Rigging assistance                   50
# 3           New ESDV-41017 & FO installation                   60
# 4        Actuator connections / Unit testing                   70
# ...                                      ...                  ...
# 518445   Caisson flange failed/missing bolts                   10
# 518446          HBA23 - HCV--30234 int. leak                   10
# 518447  Inspection by material specification                 9000
# 518448                   HWAA-TCV-34043 leak                   10
# 518449                    Stock PSV Offshore                  130
#
#                OPR_Status_ID
# 0       OV100058907500000003
# 1       OV100058907500000004
# 2       OV100058907500000005
# 3       OV100058907500000006
# 4       OV100058907500000007
# ...                      ...
# 518445  OV100051535700000001
# 518446  OV100051535800000001
# 518447                   NaN
# 518448  OV100051536000000001
# 518449  OV100019746300000013
#
# [518450 rows x 14 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ work_center ----------
#
#
#        WBS_ID  WBS_Name WBS_Plant WBS_Full_name
# 0    10001974  MTN-PIPF      DK90  DK90MTN-PIPF
# 1    10001976  VEN-TURB      DK30  DK30VEN-TURB
# 2    10001975  VEN-TURB      DK20  DK20VEN-TURB
# 3    10001977  VEN-TURB      DK70  DK70VEN-TURB
# 4    10001978  VEN-TURB      DK90  DK90VEN-TURB
# ..        ...       ...       ...           ...
# 405  10001085  MTN-TURB      DK30  DK30MTN-TURB
# 406  10001303  MTN-PAIN      DK80  DK80MTN-PAIN
# 407  10001388   CON-NPT      DK70   DK70CON-NPT
# 408  10001389   CON-NPT      DK80   DK80CON-NPT
# 409  10001390   CON-NPT      DK90   DK90CON-NPT
#
# [410 rows x 4 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ work_orders_status ----------
#
#
#         WO_Object_Number WO_Status_ID WO_Status_Profile WO_E_Status_Code  \
# 0         OR002900001515        E0003          PMMTNWOH             APPR
# 1         OR002900001515        E0017          PMMTNWOH             SMAT
# 2         OR002900001515        I0002          PMMTNWOH              NaN
# 3         OR002900001515        I0016          PMMTNWOH              NaN
# 4         OR002900001515        I0028          PMMTNWOH              NaN
# ...                  ...          ...               ...              ...
# 1189684   OR002900000516        I0028          PMMTNWOH              NaN
# 1189685   OR002900000516        I0046          PMMTNWOH              NaN
# 1189686   OR002900000516        I0215          PMMTNWOH              NaN
# 1189687   OR002900000516        I0321          PMMTNWOH              NaN
# 1189688   OR002900000516        I0420          PMMTNWOH              NaN
#
#                WO_E_Status_Message WO_I_Status_Code  \
# 0                         Approved              NaN
# 1        All Mat.Available (@Site)              NaN
# 2                              NaN              REL
# 3                              NaN              PRC
# 4                              NaN             SETC
# ...                            ...              ...
# 1189684                        NaN             SETC
# 1189685                        NaN             CLSD
# 1189686                        NaN             SSAP
# 1189687                        NaN             GMPS
# 1189688                        NaN             MANC
#
#                   WO_I_Status_Message
# 0                                 NaN
# 1                                 NaN
# 2                            Released
# 3                          Pre-costed
# 4             Settlement rule created
# ...                               ...
# 1189684       Settlement rule created
# 1189685                        Closed
# 1189686                Object created
# 1189687         Goods movement posted
# 1189688  Mat.availability not checked
#
# [1188179 rows x 7 columns]
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ------ operations_status ----------
#
#
#             OPR_Object_Number OPR_Status_ID OPR_Status_Profile  \
# 1189689  OV100058907500000003         E0002           PMMTNWOO
# 1189690  OV100058907500000003         E0004           PMMTNWOO
# 1189691  OV100058907500000003         I0002           PMMTNWOO
# 1189692  OV100058907500000004         E0002           PMMTNWOO
# 1189693  OV100058907500000004         E0004           PMMTNWOO
# ...                       ...           ...                ...
# 2728774  OV100051535800000001         E0002           PMMTNWOO
# 2728775  OV100051535800000001         E0004           PMMTNWOO
# 2728776  OV100051535800000001         I0002           PMMTNWOO
# 2728777  OV100051536000000001         E0001           PMMTNWOO
# 2728778  OV100051536000000001         I0045           PMMTNWOO
#
#         OPR_E_Status_Code   OPR_E_Status_Message OPR_I_Status_Code  \
# 1189689              APPR               Approved               NaN
# 1189690              OPND  Operation No Deletion               NaN
# 1189691               NaN                    NaN               REL
# 1189692              APPR               Approved               NaN
# 1189693              OPND  Operation No Deletion               NaN
# ...                   ...                    ...               ...
# 2728774              APPR               Approved               NaN
# 2728775              OPND  Operation No Deletion               NaN
# 2728776               NaN                    NaN               REL
# 2728777              INIT              Initiated               NaN
# 2728778               NaN                    NaN              TECO
#
#           OPR_I_Status_Message
# 1189689                    NaN
# 1189690                    NaN
# 1189691               Released
# 1189692                    NaN
# 1189693                    NaN
# ...                        ...
# 2728774                    NaN
# 2728775                    NaN
# 2728776               Released
# 2728777                    NaN
# 2728778  Technically completed
#
# [1535482 rows x 7 columns]

# %% [markdown]
# ### Some tests

# %%
### filter work order status df on status SCH
filtered_wo_status_df = wo_status_df[wo_status_df["WO_E_Status_Code"] == "SCH"]
wo_status_id = filtered_wo_status_df.WO_Object_Number.unique() 

### filter work order using work order status id of wo having SCH
filtered_wo_df = work_orders_df[work_orders_df["WO_Status_ID"].isin(wo_status_id)]
print(filtered_wo_df)
# Out:
#          WO_Number WO_Priority  WO_Functional_Location_Number  \
# 923     2100110750           3                        2528698
# 4436    2100061900           4                        1939617
# 9106    2400344885           B                        2558002
# 9114    2400350944           A                        2602608
# 9119    2400337337           C                        2529898
# ...            ...         ...                            ...
# 120791  2800024486           4                        2259821
# 120792  2800024489           4                        2259825
# 120793  2800024495           4                        2259836
# 120822  2800024369           4                        2258521
# 120824  2800024373           4                        2258535
#
#         WO_Plan_Maintenance_Number WO_Planner_Group  WO_WBS_ID WO_Revision  \
# 923                         559589              MFM   10001036         NaN
# 4436                        332984              MFM   10001444        NOSD
# 9106                        572264              MMS   10001036        NOSD
# 9114                        579184              MIN   10001167    HBD-IPHP
# 9119                        559923              MMS   10001168        NOSD
# ...                            ...              ...        ...         ...
# 120791                           0              CON   10001029    TEG-23PS
# 120792                           0              CON   10001029    TEG-23PS
# 120793                           0              CON   10001029    TEG-23PS
# 120822                           0              CON   10001029    TEG-23PS
# 120824                           0              CON   10001029    TEG-23PS
#
#        WO_Activity_Type  WO_Scheduled_Start_Date  WO_Operation_ID  ...  \
# 923                  PC               20240531.0     1.000653e+09  ...
# 4436                 PC               20240805.0     1.000372e+09  ...
# 9106                 PS               20240729.0     1.000668e+09  ...
# 9114                 PS               20241007.0     1.000676e+09  ...
# 9119                 PS               20240923.0     1.000653e+09  ...
# ...                 ...                      ...              ...  ...
# 120791               FO               20230527.0     1.000504e+09  ...
# 120792               MD               20230528.0     1.000504e+09  ...
# 120793               MD               20230529.0     1.000504e+09  ...
# 120822               FO               20230605.0     1.000503e+09  ...
# 120824               MD               20230622.0     1.000503e+09  ...
#
#        WO_Notification_Malfunction_Started WO_Notification_Created  \
# 923                             20240415.0              20240415.0
# 4436                            20220117.0              20220117.0
# 9106                            20240604.0              20240604.0
# 9114                            20240614.0              20240614.0
# 9119                            20240418.0              20240418.0
# ...                                    ...                     ...
# 120791                                 NaN                     NaN
# 120792                                 NaN                     NaN
# 120793                                 NaN                     NaN
# 120822                                 NaN                     NaN
# 120824                                 NaN                     NaN
#
#                                           WO_Notification  \
# 923      DETAILED FAULT DESCRIPTION (SPECIFICS, MEASUR...
# 4436    1: DETAILED FAULT DESCRIPTION (SPECIFICS, MEAS...
# 9106                                                  NaN
# 9114    10.09.2024 18:00:38 CET Martin Schmidt SORENSE...
# 9119                                                  NaN
# ...                                                   ...
# 120791                                                NaN
# 120792                                                NaN
# 120793                                                NaN
# 120822                                                NaN
# 120824                                                NaN
#
#        WO_Maintenance_Plan_Name WO_System_Condition  WO_Basic_Start_Date  \
# 923                         NaN                   A           20240531.0
# 4436                        NaN                   A           20240805.0
# 9106                  DKTE-0027                 NaN           20240729.0
# 9114                  DKHB-0195                   E           20241007.0
# 9119                  DKHB-0009                   C           20240923.0
# ...                         ...                 ...                  ...
# 120791                      NaN                   A           20230527.0
# 120792                      NaN                   A           20230528.0
# 120793                      NaN                   A           20230529.0
# 120822                      NaN                   A           20230605.0
# 120824                      NaN                   A           20230622.0
#
#         WO_Basic_End_Date  WO_Earliest_Allowed_Start_Date  \
# 923            20240605.0                      20240531.0
# 4436           20240820.0                      20220417.0
# 9106           20240729.0                      20240711.0
# 9114           20241007.0                      20240908.0
# 9119           20240924.0                      20240711.0
# ...                   ...                             ...
# 120791         20230527.0                             0.0
# 120792         20230528.0                             0.0
# 120793         20230529.0                             0.0
# 120822         20230605.0                             0.0
# 120824         20230622.0                             0.0
#
#         WO_Latest_Allowed_Finish_Date WO_SubNetwork_ID
# 923                        20241013.0              NaN
# 4436                       20220914.0              NaN
# 9106                       20240727.0              NaN
# 9114                       20241008.0              NaN
# 9119                       20240816.0              NaN
# ...                               ...              ...
# 120791                            0.0              NaN
# 120792                            0.0              NaN
# 120793                            0.0              NaN
# 120822                            0.0              NaN
# 120824                            0.0              NaN
#
# [2780 rows x 27 columns]

# %%
look_for_location = "?0100000000000647856"

# filter functional location df
filtered_functional_location_df = functional_locations_df[functional_locations_df["FLOC_Functional_ID"] == look_for_location]

print(filtered_functional_location_df)

# get functional location of work order 2100035861
filtered_wo_df = work_orders_df[work_orders_df["WO_Functional_Location_Number"].isin(filtered_functional_location_df["FLOC_Technical_ID"].unique())]

print(filtered_wo_df["WO_Number"].unique())

#
# Out:
#         FLOC_Technical_ID    FLOC_Functional_ID            FLOC_Name  \
# 69317             1255398  ?0100000000000647856  GO /C /78/GC-M-710A
# 144225            1348374  ?0100000000000647856  GO /C /78/GC-M-710A
# 144415            1365335  ?0100000000000647856  GO /C /78/GC-M-710A
# 145260            1368871  ?0100000000000647856  GO /C /78/GC-M-710A
# 145510            1347739  ?0100000000000647856  GO /C /78/GC-M-710A
# ...                   ...                   ...                  ...
# 478516            2649413  ?0100000000000647856  GO /C /78/GC-M-710A
# 478602            2651807  ?0100000000000647856  GO /C /78/GC-M-710A
# 483481            2688772  ?0100000000000647856  GO /C /78/GC-M-710A
# 487223            2701588  ?0100000000000647856  GO /C /78/GC-M-710A
# 487225            2701587  ?0100000000000647856  GO /C /78/GC-M-710A
#
#        ILOAN_Location_Room FLOC_Plant_Code
# 69317                  NaN            DK80
# 144225                 NaN            DK80
# 144415                 NaN            DK80
# 145260                 NaN            DK80
# 145510                 NaN            DK80
# ...                    ...             ...
# 478516                 NaN            DK80
# 478602                 NaN            DK80
# 483481                 NaN            DK80
# 487223                 NaN            DK80
# 487225                 NaN            DK80
#
# [234 rows x 5 columns]
# [2100119264 2400376870 2100035909 2100035921 2100035922 2100035923
#  2100035924 2100035925 2100035939 2400336890 2400342656 2100066369
#  2100070189 2100060447 2100034971 2100106459 2100103431 2100103881
#  2400302359 2100091760 2400269361 2100089880 2100035919 2100077382
#  2400105953 2100042176 2100022687 2100024009 2100103685 2100112475
#  2100111968 2300002280 2100029630 2100035517 2100035520 2100035514
#  2400134530 2100035903 2100035908 2100035920 2400116372 2400069705
#  2400244593 2400244287 2400244294 2100079544 2400244592 2400241897
#  2100069675 2100079491 2100079492 2100079493 2400240452 2400240453
#  2400240487 2100061515 2400214335 2400192419 2100062000 2400190889
#  2100060511 2100062596 2100051699 2100057936 2400150914 2100047032
#  2100058730 2400177151 2400051041 2400052995 2100055173 2400053133
#  2400051626 2400050926 2400051886 2400066378 2100052767 2100054260
#  2400105538 2100045800 2100042183 2100051700 2100024097 2100023346
#  2100023090 2100023198 2100023199 2100023312 2100022349 2100022442
#  2100022615 2100022660 2100023504 2100023996 2400129022 2400078244
#  2100034972 2400307768 2100094220 2100094221 2400272973 2100091759
#  2100088941 2400268407 2400268406]

# %% [markdown]
# ### API-Like functions

# %%
def get_int_data(data):
    return str(data).replace(".0", "") if not pd.isnull(data) else "-"

def get_wbs_data(wbs_id):
    # Extract from the wbs df the concerned wbs
    wbs_tmp_df = wbs_df[wbs_df["WBS_ID"] == wbs_id]
    if len(wbs_tmp_df) == 0:
        return "None"
    
    wbs_data = wbs_tmp_df.iloc[0]

    return {
        "ID": wbs_id,
        "Name": wbs_data["WBS_Name"],
        "Plant": wbs_data["WBS_Plant"],
        "Full_Name": wbs_data["WBS_Full_name"]
    }

def get_status_data(status_number: str):

    def get_column_name(is_wo, suffix_column_name):
        return "_".join(["WO" if is_wo else "OPR", suffix_column_name])

    def get_status_filtered_df(is_wo):
        df_to_filter = wo_status_df if is_wo else opr_status_df

        return df_to_filter[df_to_filter[get_column_name(is_wo, "Object_Number")] == status_number]

    # It needs to know if the status is linked to a WO or to an Operation
    is_wo = status_number.startswith("OR")

    # Get status related to the work order
    status_tmp_df = get_status_filtered_df(is_wo)
    
    e_status = []
    i_status = []

    for index, row in status_tmp_df.iterrows():
        if row[get_column_name(is_wo, "Status_ID")].startswith("E"):
            e_status.append({
                "ID": row[get_column_name(is_wo, "Status_ID")],
                "Profile": row[get_column_name(is_wo, "Status_Profile")],
                "Code": row[get_column_name(is_wo, "E_Status_Code")],
                "Message": row[get_column_name(is_wo, "E_Status_Message")],
            })
        elif row[get_column_name(is_wo, "Status_ID")].startswith("I"):
            i_status.append({
                "ID": row[get_column_name(is_wo, "Status_ID")],
                "Profile": row[get_column_name(is_wo, "Status_Profile")],
                "Code": row[get_column_name(is_wo, "I_Status_Code")],
                "Message": row[get_column_name(is_wo, "I_Status_Message")],
            })

    return {
        "Status_ID": status_number,
        "E_Status": e_status,
        "I_Status": i_status
    }

def get_operations_data(wo_operation_id, wo_status):
    # Get operations for the WO
    opr_tmp_df = operations_df[operations_df["OPR_Routing_Number"] == wo_operation_id].sort_values(["OPR_Counter"])

    # Get scheduled data or not depending on the WO status contains SCH
    #is_scheduled = len(filter(lambda stat: stat["Code"] == "SCH", wo_status["E_Status"])) == 1
    is_scheduled = len([status for status in wo_status["E_Status"] if status["Code"] == "SCH"]) == 1

    # Format in json
    res = []
    for index, row in opr_tmp_df.iterrows():
        res.append({
            "Counter": row["OPR_Counter"],
            "Workers_Numbers": row["OPR_Workers_Numbers"],
            "Planned_Work": row["OPR_Planned_Work"],
            "Actual_Work": row["OPR_Actual_Work"],
            "Work_Start_Date": get_int_data(row["OPR_Start_Date"]),
            "Work_Start_Time": get_int_data(row["OPR_Start_Time"]),
            "Work_End_Date": get_int_data(row["OPR_End_Date"]),
            "Work_End_Time": get_int_data(row["OPR_End_Time"]),
            "Scheduled_Work": row["OPR_Scheduled_Work"] if is_scheduled else "-",
            "Work_Center": get_wbs_data(row["OPR_WBS_ID"]),
            "Status": get_status_data(row["OPR_Status_ID"]),
            "Operation_Short_Text": row["OPR_Description"]
        })

    return res

def get_location_data(location_number):
    loc_tmp_df = functional_locations_df[functional_locations_df["FLOC_Technical_ID"] == location_number]
    # Extract from the functional location df the concerned location
    if len(loc_tmp_df) == 0:
        return "None"
    elif len(loc_tmp_df) > 1:
        raise Exception("Too much locations have been found for this id ", location_number)
    
    loc_data = loc_tmp_df.iloc[0]

    #print(loc_data)

    return {
        "ID": loc_data["FLOC_Technical_ID"],
        "Name": loc_data["FLOC_Name"],
        "Plant": loc_data["FLOC_Plant_Code"]
    }

def get_plan_maintenance(plan_number):
    #print(plan_number)
    pm_tmp_df = plan_maintenance_location_df[plan_maintenance_location_df["PM_Object_Number"] == plan_number].merge(functional_locations_df, how = "left", left_on=["PM_Functional_Location"], right_on = ["FLOC_Technical_ID"]).sort_values(["PM_Object_Sorting"])

    secondary_locations = []
    for index, row in pm_tmp_df.iterrows():
        secondary_locations.append({
            "ID": row["FLOC_Technical_ID"],
            "Counter": row["PM_Object_Sorting"],
            "Name": row["FLOC_Name"]
        })

    #print(pm_tmp_df)

    return secondary_locations

def get_work_order_data(work_order_id):

    # Extract from the work order df the concerned wo
    wo_tmp_df = work_orders_df[work_orders_df["WO_Number"] == work_order_id]
    if len(wo_tmp_df) == 0:
        raise Exception("Impossible to pursue, no work order found for this id ", work_order_id)
    
    wo_data = wo_tmp_df.iloc[0]

    #print(wo_data)

    # Operations
    #print(get_operations_data(wo_data["WO_Operation_ID"]))
    # Functional Location
    #print(get_location_data(wo_data["WO_Functional_Location_Number"]))
    # Get WBS
    #print(get_wbs_data(wo_data["WO_WBS_ID"]))
    # Work Order status
    #print(get_status_data(wo_data["WO_Status_ID"]))
    # Plan maintenance - secondary locations
    #print(get_plan_maintenance(wo_data["WO_Plan_Maintenance_Number"]))

    wo_status = get_status_data(wo_data["WO_Status_ID"])
    
    return {
        "ID": wo_data["WO_Number"],
        "Priority": wo_data["WO_Priority"],
        "Planner_Group": wo_data["WO_Planner_Group"],
        "Revision": wo_data["WO_Revision"],
        "Activity_Type": wo_data["WO_Activity_Type"],
        "Order_Type": wo_data["WO_Order_Type"],
        "Scheduled_Start_Date": get_int_data(wo_data["WO_Scheduled_Start_Date"]),
        "Phase_Order_Created": get_int_data(wo_data["WO_Phase_Order_Created"]),
        "Phase_Order_Released": get_int_data(wo_data["WO_Phase_Order_Released"]),
        "Original_Deadline": get_int_data(wo_data["WO_Original_Deadline"]),
        "Header_Description": wo_data["WO_Header_Description"],
        "Operations_ID": get_int_data(wo_data["WO_Operation_ID"]),
        "Operations": get_operations_data(wo_data["WO_Operation_ID"], wo_status),
        "Status": wo_status,
        "Location": get_location_data(wo_data["WO_Functional_Location_Number"]),
        "Plan_Maintenance": get_plan_maintenance(wo_data["WO_Plan_Maintenance_Number"]),
        "Work_Center": get_wbs_data(wo_data["WO_WBS_ID"]),
        "Notification_Number": get_int_data(wo_data["WO_Notification_Number"]),
        "Notification_Created": get_int_data(wo_data["WO_Notification_Created"]),
        "Notification_Malfunction_Started": get_int_data(wo_data["WO_Notification_Malfunction_Started"]),
        "Notification": wo_data["WO_Notification"],
        "Earliest_Allowed_Start_Date": wo_data["WO_Earliest_Allowed_Start_Date"],
        "Latest_Allowed_Finish_Date": wo_data["WO_Latest_Allowed_Finish_Date"],
        "Basic_Start_Date": wo_data["WO_Basic_Start_Date"],
        "Basic_End_Date": wo_data["WO_Basic_End_Date"],
        "System_Condition": wo_data["WO_System_Condition"],
        "Maintenance_Plan_Name": wo_data["WO_Maintenance_Plan_Name"]
    }

pprint.pprint(get_work_order_data(2100024286))
# Out:
# {'Activity_Type': 'DE',
#  'Basic_End_Date': 20210206.0,
#  'Basic_Start_Date': 20201109.0,
#  'Earliest_Allowed_Start_Date': 20191013.0,
#  'Header_Description': 'ANOS HGS19-1-2 GOC module 2 repl. gratin',
#  'ID': 2100024286,
#  'Latest_Allowed_Finish_Date': 20200311.0,
#  'Location': {'ID': 1370910,
#               'Name': 'GO /C /86/30375 - GRATINGS',
#               'Plant': 'DK80'},
#  'Maintenance_Plan_Name': nan,
#  'Notification': ' DETAILED FAULT DESCRIPTION(SPECIFICS, MEASSURABLES, '
#                  'LOCATION)\n'
#                  'nding from handrail and grating survey March 2019\n'
#                  'cation:  GOC 30.350 Module 2\n'
#                  'nding no.: 1, 3\n'
#                  'iticality: 2\n'
#                  'nding 1: Grating unsupportet and corroded - needs attention\n'
#                  'nding 3: Grating in staircase towards GOD side of GOC worn '
#                  'out and\n'
#                  'vered with scaffolding plate\n'
#                  'ndor from Semco ongoing with fabrication drawings\n'
#                  'nan\n'
#                  ' INVESTIGATION OR MITIGATION REQUIRED?\n'
#                  ' mitigation, offshore is putting out deck plates and '
#                  'replacing steps\n'
#                  ' stairs, where needed.\n'
#                  'nan\n'
#                  ' SPECIAL REQUIREMENTS (MATERIALS, TOOLS OR TRADES)\n'
#                  'nan\n'
#                  'nan\n'
#                  ' RELEVANT INFORMATION (P + ID/PIC/ESTIMATES/PARTLIST/ZMOG)\n'
#                  'adplan\n'
#                  'ctures',
#  'Notification_Created': '20200128',
#  'Notification_Malfunction_Started': '20190712',
#  'Notification_Number': '1500001446',
#  'Operations': [{'Actual_Work': 0.0,
#                  'Counter': 1,
#                  'Operation_Short_Text': 'RW HGS19-1 GOC module 2 repl. '
#                                          'grating',
#                  'Planned_Work': 0.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000001'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20210205',
#                  'Work_End_Time': '181354',
#                  'Work_Start_Date': '20210205',
#                  'Work_Start_Time': '181354',
#                  'Workers_Numbers': 0},
#                 {'Actual_Work': 0.0,
#                  'Counter': 2,
#                  'Operation_Short_Text': '****Job 1- on stair *****',
#                  'Planned_Work': 0.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000002'},
#                  'Work_Center': {'Full_Name': 'DK80PRODTECH',
#                                  'ID': 10001309,
#                                  'Name': 'PRODTECH',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20210205',
#                  'Work_End_Time': '181354',
#                  'Work_Start_Date': '20210205',
#                  'Work_Start_Time': '181354',
#                  'Workers_Numbers': 0},
#                 {'Actual_Work': 0.0,
#                  'Counter': 3,
#                  'Operation_Short_Text': 'Prepare Job - make permits - Weld',
#                  'Planned_Work': 10.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000003'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '54737',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 4,
#                  'Operation_Short_Text': 'Prepare Job - make permits - scaff',
#                  'Planned_Work': 10.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000004'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '54830',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 5,
#                  'Operation_Short_Text': 'Demol old Grating on stair - weld',
#                  'Planned_Work': 15.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000005'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '54845',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 6,
#                  'Operation_Short_Text': 'Demol old Grating on stair - Scaff',
#                  'Planned_Work': 15.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000006'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '54942',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 7,
#                  'Operation_Short_Text': 'Clean and Paint topflange - Paint',
#                  'Planned_Work': 17.4,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000007'},
#                  'Work_Center': {'Full_Name': 'DK80CON-PAIN',
#                                  'ID': 10001289,
#                                  'Name': 'CON-PAIN',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '90814',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 8,
#                  'Operation_Short_Text': 'Paint escape arrow on grating - '
#                                          'Paint',
#                  'Planned_Work': 4.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000008'},
#                  'Work_Center': {'Full_Name': 'DK80CON-PAIN',
#                                  'ID': 10001289,
#                                  'Name': 'CON-PAIN',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '90836',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 9,
#                  'Operation_Short_Text': 'Mount 3 pcs. new Grating on stair - '
#                                          'Weld',
#                  'Planned_Work': 15.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000009'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '55127',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 10,
#                  'Operation_Short_Text': 'Mount 3 pcs. new Grating on stair- '
#                                          'Scaff',
#                  'Planned_Work': 15.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000010'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201112',
#                  'Work_End_Time': '203739',
#                  'Work_Start_Date': '20201112',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 11,
#                  'Operation_Short_Text': '*** Job 2 - Between skid and '
#                                          'clycon***',
#                  'Planned_Work': 0.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000011'},
#                  'Work_Center': {'Full_Name': 'DK80PRODTECH',
#                                  'ID': 10001309,
#                                  'Name': 'PRODTECH',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20210205',
#                  'Work_End_Time': '181354',
#                  'Work_Start_Date': '20210205',
#                  'Work_Start_Time': '181354',
#                  'Workers_Numbers': 0},
#                 {'Actual_Work': 0.0,
#                  'Counter': 12,
#                  'Operation_Short_Text': 'Prepare Job - make permits - Weld',
#                  'Planned_Work': 10.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000012'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '55144',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 13,
#                  'Operation_Short_Text': 'Prepare Job - make permits - scaff',
#                  'Planned_Work': 10.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000013'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201112',
#                  'Work_End_Time': '203815',
#                  'Work_Start_Date': '20201112',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 14,
#                  'Operation_Short_Text': 'Demol old Grating on stair - weld',
#                  'Planned_Work': 20.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000014'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '55228',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 15,
#                  'Operation_Short_Text': 'Demol old Grating on stair - Scaff',
#                  'Planned_Work': 20.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000015'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201204',
#                  'Work_End_Time': '131601',
#                  'Work_Start_Date': '20201106',
#                  'Work_Start_Time': '160000',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 16,
#                  'Operation_Short_Text': 'Clean and Paint topflange - Paint',
#                  'Planned_Work': 17.4,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000016'},
#                  'Work_Center': {'Full_Name': 'DK80CON-PAIN',
#                                  'ID': 10001289,
#                                  'Name': 'CON-PAIN',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20210201',
#                  'Work_End_Time': '153700',
#                  'Work_Start_Date': '20210131',
#                  'Work_Start_Time': '160000',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 17,
#                  'Operation_Short_Text': 'Paint escape arrow on grating - '
#                                          'Paint',
#                  'Planned_Work': 4.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000017'},
#                  'Work_Center': {'Full_Name': 'DK80CON-PAIN',
#                                  'ID': 10001289,
#                                  'Name': 'CON-PAIN',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20210206',
#                  'Work_End_Time': '91714',
#                  'Work_Start_Date': '20210205',
#                  'Work_Start_Time': '181354',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 18,
#                  'Operation_Short_Text': 'Mount 3-4 pcs new grating- Weld',
#                  'Planned_Work': 20.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000018'},
#                  'Work_Center': {'Full_Name': 'DK80CON-WELD',
#                                  'ID': 10001293,
#                                  'Name': 'CON-WELD',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201110',
#                  'Work_End_Time': '55609',
#                  'Work_Start_Date': '20201110',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 19,
#                  'Operation_Short_Text': 'Mount 3-4 pcs new grating- Scaff',
#                  'Planned_Work': 20.1,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'CNF',
#                                           'ID': 'I0009',
#                                           'Message': 'Confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000019'},
#                  'Work_Center': {'Full_Name': 'DK80CON-SCAF',
#                                  'ID': 10001292,
#                                  'Name': 'CON-SCAF',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201112',
#                  'Work_End_Time': '203858',
#                  'Work_Start_Date': '20201112',
#                  'Work_Start_Time': '0',
#                  'Workers_Numbers': 2},
#                 {'Actual_Work': 0.0,
#                  'Counter': 20,
#                  'Operation_Short_Text': 'Matriale bestillling til smede '
#                                          '08.07.20',
#                  'Planned_Work': 0.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'PCNF',
#                                           'ID': 'I0010',
#                                           'Message': 'Partially confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000020'},
#                  'Work_Center': {'Full_Name': 'DK80PRODTECH',
#                                  'ID': 10001309,
#                                  'Name': 'PRODTECH',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201118',
#                  'Work_End_Time': '120000',
#                  'Work_Start_Date': '20201118',
#                  'Work_Start_Time': '120000',
#                  'Workers_Numbers': 0},
#                 {'Actual_Work': 0.0,
#                  'Counter': 21,
#                  'Operation_Short_Text': 'MATERIAL WELDER GRATING 04.08.20',
#                  'Planned_Work': 0.0,
#                  'Scheduled_Work': '-',
#                  'Status': {'E_Status': [{'Code': 'APPR',
#                                           'ID': 'E0002',
#                                           'Message': 'Approved',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'OPND',
#                                           'ID': 'E0004',
#                                           'Message': 'Operation No Deletion',
#                                           'Profile': 'PMMTNWOO'}],
#                             'I_Status': [{'Code': 'REL',
#                                           'ID': 'I0002',
#                                           'Message': 'Released',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'PCNF',
#                                           'ID': 'I0010',
#                                           'Message': 'Partially confirmed',
#                                           'Profile': 'PMMTNWOO'},
#                                          {'Code': 'MCNF',
#                                           'ID': 'I0052',
#                                           'Message': 'Manually confirmed',
#                                           'Profile': 'PMMTNWOO'}],
#                             'Status_ID': 'OV100012280200000021'},
#                  'Work_Center': {'Full_Name': 'DK80PRODTECH',
#                                  'ID': 10001309,
#                                  'Name': 'PRODTECH',
#                                  'Plant': 'DK80'},
#                  'Work_End_Date': '20201118',
#                  'Work_End_Time': '110000',
#                  'Work_Start_Date': '20201118',
#                  'Work_Start_Time': '110000',
#                  'Workers_Numbers': 0}],
#  'Operations_ID': '1000122802',
#  'Order_Type': 'WDF',
#  'Original_Deadline': '20200311',
#  'Phase_Order_Created': '-',
#  'Phase_Order_Released': 'X',
#  'Plan_Maintenance': [],
#  'Planner_Group': 'MFM',
#  'Priority': '4',
#  'Revision': 'NOSD',
#  'Scheduled_Start_Date': '20201109',
#  'Status': {'E_Status': [{'Code': 'APPR',
#                           'ID': 'E0003',
#                           'Message': 'Approved',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'WTA',
#                           'ID': 'E0011',
#                           'Message': 'Awaiting Technical Approval',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'CMAT',
#                           'ID': 'E0016',
#                           'Message': 'All Mat.Available (@Base)',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'RDBL',
#                           'ID': 'E0029',
#                           'Message': 'Route Disabled',
#                           'Profile': 'PMMTNWOH'}],
#             'I_Status': [{'Code': 'REL',
#                           'ID': 'I0002',
#                           'Message': 'Released',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'PPRT',
#                           'ID': 'I0008',
#                           'Message': 'Part printed',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'PCNF',
#                           'ID': 'I0010',
#                           'Message': 'Partially confirmed',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'PRC',
#                           'ID': 'I0016',
#                           'Message': 'Pre-costed',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'SETC',
#                           'ID': 'I0028',
#                           'Message': 'Settlement rule created',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'SSAP',
#                           'ID': 'I0215',
#                           'Message': 'Object created',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'GMPS',
#                           'ID': 'I0321',
#                           'Message': 'Goods movement posted',
#                           'Profile': 'PMMTNWOH'},
#                          {'Code': 'MANC',
#                           'ID': 'I0420',
#                           'Message': 'Mat.availability not checked',
#                           'Profile': 'PMMTNWOH'}],
#             'Status_ID': 'OR002100024286'},
#  'System_Condition': 'A',
#  'Work_Center': {'Full_Name': 'DK80MTN-ROPE',
#                  'ID': 10001444,
#                  'Name': 'MTN-ROPE',
#                  'Plant': 'DK80'}}
